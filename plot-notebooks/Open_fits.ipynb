# %%
from astropy.io import fits
import numpy as np

# Load the first FITS file
file1_path = '../data/dv/sim_map3-NLA-cosmogrid-20May24.fits'
hdul1 = fits.open(file1_path)

# Print information about the first FITS file
print("Info about the first FITS file:")
print(hdul1[3].header)
print(hdul1[3].data)

#x = []
#for i in range(80):
#    x.append(hdul1[1].data[i][6])
#print(x)

#y = np.array(x)
#np.save("Theory_map3_cosmogrid-20May24", y)

# Load the second FITS file
#file2_path = '../data/dv/sim_map3_emu_300ups.fits'
#hdul2 = fits.open(file2_path)

#x = []
#for i in range(80):
#    x.append(hdul2[1].data[i][6])
#print(x)

#z = np.array(x)
#np.save("Synthetic_theory_map3_cosmoDESY3-emu_300ups", z)

# Print information about the second FITS file
#print("\nInfo about the second FITS file:")
#print(hdul2[1].data)

# Don't forget to close the files when you're done
hdul1.close()
#hdul2.close()
# Out:
# Info about the first FITS file:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 10
#       8 # Print information about the first FITS file
#       9 print("Info about the first FITS file:")
# ---> 10 print(hdul1[3].header)
#      11 print(hdul1[3].data)
#      13 #x = []
#      14 #for i in range(80):
#      15 #    x.append(hdul1[1].data[i][6])
#    (...)
#      36
#      37 # Don't forget to close the files when you're done
#
# File ~/miniconda3/envs/cp_env/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:395, in HDUList.__getitem__(self, key)
#     392 except IndexError as e:
#     393     # Raise a more helpful IndexError if the file was not fully read.
#     394     if self._read_all:
# --> 395         raise e
#     396     else:
#     397         raise IndexError(
#     398             "HDU not found, possibly because the index "
#     399             "is out of range, or because the file was "
#     400             "closed before all HDUs were read"
#     401         )
#
# File ~/miniconda3/envs/cp_env/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:389, in HDUList.__getitem__(self, key)
#     385 # Originally this used recursion, but hypothetically an HDU with
#     386 # a very large number of HDUs could blow the stack, so use a loop
#     387 # instead
#     388 try:
# --> 389     return self._try_while_unread_hdus(
#     390         super().__getitem__, self._positive_index_of(key)
#     391     )
#     392 except IndexError as e:
#     393     # Raise a more helpful IndexError if the file was not fully read.
#     394     if self._read_all:
#
# File ~/miniconda3/envs/cp_env/lib/python3.10/site-packages/astropy/io/fits/hdu/hdulist.py:1258, in HDUList._try_while_unread_hdus(self, func, *args, **kwargs)
#    1256 while True:
#    1257     try:
# -> 1258         return func(*args, **kwargs)
#    1259     except Exception:
#    1260         if self._read_next_hdu():
#
# IndexError: list index out of range
