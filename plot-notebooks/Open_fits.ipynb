# %%
from astropy.io import fits

# Load the first FITS file
file1_path = '../data/dv/sim_map3-NLA-cosmoDESY3-14May24.fits'
hdul1 = fits.open(file1_path)

# Print information about the first FITS file
print("Info about the first FITS file:")
print(hdul1[1].data)

# Load the second FITS file
file2_path = '../data/dv/sim_map3-NLA-cosmoDESY3.fits'
hdul2 = fits.open(file2_path)

# Print information about the second FITS file
print("\nInfo about the second FITS file:")
print(hdul2[1].data)

# Don't forget to close the files when you're done
hdul1.close()
hdul2.close()
# Out:
# Info about the first FITS file:
# [(1, 1, 1,  7.,  7.,  7., 1.45186192e-10)
#  (1, 1, 1, 14., 14., 14., 6.08920000e-11)
#  (1, 1, 1, 25., 25., 25., 1.33114825e-11)
#  (1, 1, 1, 40., 40., 40., 2.14687581e-12)
#  (1, 1, 2,  7.,  7.,  7., 2.48111488e-10)
#  (1, 1, 2, 14., 14., 14., 9.96687097e-11)
#  (1, 1, 2, 25., 25., 25., 2.11697895e-11)
#  (1, 1, 2, 40., 40., 40., 3.35593425e-12)
#  (1, 1, 3,  7.,  7.,  7., 2.81655558e-10)
#  (1, 1, 3, 14., 14., 14., 1.12060153e-10)
#  (1, 1, 3, 25., 25., 25., 2.36694593e-11)
#  (1, 1, 3, 40., 40., 40., 3.73979929e-12)
#  (1, 1, 4,  7.,  7.,  7., 2.88302089e-10)
#  (1, 1, 4, 14., 14., 14., 1.14391934e-10)
#  (1, 1, 4, 25., 25., 25., 2.41250386e-11)
#  (1, 1, 4, 40., 40., 40., 3.80834777e-12)
#  (1, 2, 2,  7.,  7.,  7., 4.55491002e-10)
#  (1, 2, 2, 14., 14., 14., 1.73735146e-10)
#  (1, 2, 2, 25., 25., 25., 3.59586807e-11)
#  (1, 2, 2, 40., 40., 40., 5.61469140e-12)
#  (1, 2, 3,  7.,  7.,  7., 5.30590248e-10)
# ...
