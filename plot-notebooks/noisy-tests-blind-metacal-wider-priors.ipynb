# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
import sys
sys.path.append('../python')
import utils
import threepoint

# %%
blind = True

all_sims1 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-001.txt', to_mcsamples=True, blind=blind)
#map3_all_sims1 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut/des-y3-map3-all-001.txt', to_mcsamples=True, blind=blind)
twpt_all_sims1 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-001.txt', to_mcsamples=True, blind=blind)
# Out:
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
all_sims2 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-002.txt', to_mcsamples=True, blind=blind)
twpt_all_sims2 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-002.txt', to_mcsamples=True, blind=blind)
# Out:
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
all_sims3 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-003.txt', to_mcsamples=True, blind=blind)
twpt_all_sims3 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-003.txt', to_mcsamples=True, blind=blind)
# Out:
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
all_sims4 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-004.txt', to_mcsamples=True, blind=blind)
twpt_all_sims4 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-004.txt', to_mcsamples=True, blind=blind)
all_sims5 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-005.txt', to_mcsamples=True, blind=blind)
twpt_all_sims5 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-005.txt', to_mcsamples=True, blind=blind)
all_sims6 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-006.txt', to_mcsamples=True, blind=blind)
twpt_all_sims6 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-006.txt', to_mcsamples=True, blind=blind)
# Out:
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
all_sims7 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-007.txt', to_mcsamples=True, blind=blind)
twpt_all_sims7 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-007.txt', to_mcsamples=True, blind=blind)
all_sims8 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-008.txt', to_mcsamples=True, blind=blind)
twpt_all_sims8 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-008.txt', to_mcsamples=True, blind=blind)
all_sims9 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-009.txt', to_mcsamples=True, blind=blind)
twpt_all_sims9 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-009.txt', to_mcsamples=True, blind=blind)
all_sims10 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-010.txt', to_mcsamples=True, blind=blind)
twpt_all_sims10 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-010.txt', to_mcsamples=True, blind=blind)
all_sims11 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-011.txt', to_mcsamples=True, blind=blind)
twpt_all_sims11 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-011.txt', to_mcsamples=True, blind=blind)
all_sims12 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-012.txt', to_mcsamples=True, blind=blind)
twpt_all_sims12 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-012.txt', to_mcsamples=True, blind=blind)
all_sims13 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-013.txt', to_mcsamples=True, blind=blind)
twpt_all_sims13 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-013.txt', to_mcsamples=True, blind=blind)
all_sims14 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-014.txt', to_mcsamples=True, blind=blind)
twpt_all_sims14 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-014.txt', to_mcsamples=True, blind=blind)
all_sims15 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-015.txt', to_mcsamples=True, blind=blind)
twpt_all_sims15 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-015.txt', to_mcsamples=True, blind=blind)
all_sims16 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-016.txt', to_mcsamples=True, blind=blind)
twpt_all_sims16 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-016.txt', to_mcsamples=True, blind=blind)
all_sims17 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-017.txt', to_mcsamples=True, blind=blind)
twpt_all_sims17 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-017.txt', to_mcsamples=True, blind=blind)
all_sims18 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-018.txt', to_mcsamples=True, blind=blind)
twpt_all_sims18 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-018.txt', to_mcsamples=True, blind=blind)
all_sims19 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-019.txt', to_mcsamples=True, blind=blind)
twpt_all_sims19 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-019.txt', to_mcsamples=True, blind=blind)
all_sims20 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-020.txt', to_mcsamples=True, blind=blind)
twpt_all_sims20 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-020.txt', to_mcsamples=True, blind=blind)
all_sims21 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-021.txt', to_mcsamples=True, blind=blind)
twpt_all_sims21 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-021.txt', to_mcsamples=True, blind=blind)
all_sims22 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-022.txt', to_mcsamples=True, blind=blind)
twpt_all_sims22 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-022.txt', to_mcsamples=True, blind=blind)
all_sims23 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-023.txt', to_mcsamples=True, blind=blind)
twpt_all_sims23 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-023.txt', to_mcsamples=True, blind=blind)
all_sims24 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-024.txt', to_mcsamples=True, blind=blind)
twpt_all_sims24 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-024.txt', to_mcsamples=True, blind=blind)
all_sims25 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-025.txt', to_mcsamples=True, blind=blind)
twpt_all_sims25 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-025.txt', to_mcsamples=True, blind=blind)
all_sims26 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-026.txt', to_mcsamples=True, blind=blind)
twpt_all_sims26 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-026.txt', to_mcsamples=True, blind=blind)
all_sims27 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-027.txt', to_mcsamples=True, blind=blind)
twpt_all_sims27 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-027.txt', to_mcsamples=True, blind=blind)
# Out:
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ...

# %%
all_sims28 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-028.txt', to_mcsamples=True, blind=blind)
twpt_all_sims28 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-028.txt', to_mcsamples=True, blind=blind)
all_sims29 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-029.txt', to_mcsamples=True, blind=blind)
twpt_all_sims29 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-029.txt', to_mcsamples=True, blind=blind)
all_sims30 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-030.txt', to_mcsamples=True, blind=blind)
twpt_all_sims30 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-030.txt', to_mcsamples=True, blind=blind)
all_sims31 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-031.txt', to_mcsamples=True, blind=blind)
twpt_all_sims31 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-031.txt', to_mcsamples=True, blind=blind)
all_sims32 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-032.txt', to_mcsamples=True, blind=blind)
twpt_all_sims32 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-032.txt', to_mcsamples=True, blind=blind)
all_sims33 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-033.txt', to_mcsamples=True, blind=blind)
twpt_all_sims33 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-033.txt', to_mcsamples=True, blind=blind)
all_sims34 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-034.txt', to_mcsamples=True, blind=blind)
twpt_all_sims34 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-034.txt', to_mcsamples=True, blind=blind)
all_sims35 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-035.txt', to_mcsamples=True, blind=blind)
twpt_all_sims35 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-035.txt', to_mcsamples=True, blind=blind)
all_sims36 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-036.txt', to_mcsamples=True, blind=blind)
twpt_all_sims36 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-036.txt', to_mcsamples=True, blind=blind)
all_sims37 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-037.txt', to_mcsamples=True, blind=blind)
twpt_all_sims37 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-037.txt', to_mcsamples=True, blind=blind)
all_sims38 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-038.txt', to_mcsamples=True, blind=blind)
twpt_all_sims38 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-038.txt', to_mcsamples=True, blind=blind)
all_sims39 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-039.txt', to_mcsamples=True, blind=blind)
twpt_all_sims39 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-039.txt', to_mcsamples=True, blind=blind)
all_sims40 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-040.txt', to_mcsamples=True, blind=blind)
twpt_all_sims40 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-040.txt', to_mcsamples=True, blind=blind)
all_sims41 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-041.txt', to_mcsamples=True, blind=blind)
twpt_all_sims41 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-041.txt', to_mcsamples=True, blind=blind)
all_sims42 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-042.txt', to_mcsamples=True, blind=blind)
twpt_all_sims42 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-042.txt', to_mcsamples=True, blind=blind)
all_sims43 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-043.txt', to_mcsamples=True, blind=blind)
twpt_all_sims43 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-043.txt', to_mcsamples=True, blind=blind)
all_sims44 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-044.txt', to_mcsamples=True, blind=blind)
twpt_all_sims44 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-044.txt', to_mcsamples=True, blind=blind)
all_sims45 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-045.txt', to_mcsamples=True, blind=blind)
twpt_all_sims45 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-045.txt', to_mcsamples=True, blind=blind)
all_sims46 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-046.txt', to_mcsamples=True, blind=blind)
twpt_all_sims46 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-046.txt', to_mcsamples=True, blind=blind)
all_sims47 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-047.txt', to_mcsamples=True, blind=blind)
twpt_all_sims47 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-047.txt', to_mcsamples=True, blind=blind)
all_sims48 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-048.txt', to_mcsamples=True, blind=blind)
twpt_all_sims48 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-048.txt', to_mcsamples=True, blind=blind)
all_sims49 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-049.txt', to_mcsamples=True, blind=blind)
twpt_all_sims49 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-049.txt', to_mcsamples=True, blind=blind)
all_sims50 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-map3-all-050.txt', to_mcsamples=True, blind=blind)
twpt_all_sims50 = utils.read_cosmosis_mcmc_des_chain('../output/noisy-cosmogridc-simdv-joint-2pt-moped-run-8arcmincut-december/des-y3-2pt-500simcov-050.txt', to_mcsamples=True, blind=blind)
# Out:
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ...

# %%
blind = True
file1 = '../output/blind-metacal-updatedcov/des-y3-2pt-blind-metacal-simcov.txt'
file2 = '../output/blind-metacal-8arcmincut-december/des-y3-2pt-map3-all-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly, desy3_joint = chains[0], chains[1]
# Out:
# ../output/blind-metacal-updatedcov/des-y3-2pt-blind-metacal-simcov.txt
# 8
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-december/des-y3-2pt-map3-all-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
blind = True
file1 = '../output/blind-metacal-8arcmincut-december/des-y3-2pt-blind-metacal-simcov.txt'
file2 = '../output/blind-metacal-8arcmincut-december/des-y3-2pt-map3-all-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly2, desy3_joint = chains[0], chains[1]
# Out:
# ../output/blind-metacal-8arcmincut-december/des-y3-2pt-blind-metacal-simcov.txt
# 8
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-december/des-y3-2pt-map3-all-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
blind = True
file1 = '../output/blind-metacal-updatedcov/des-y3-2pt-blind-metacal-simcov.txt'
file2 = '../output/blind-metacal-8arcmincut-december/des-y3-map3-all-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly, desy3_map3only = chains[0], chains[1]
# Out:
# ../output/blind-metacal-updatedcov/des-y3-2pt-blind-metacal-simcov.txt
# 8
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-december/des-y3-map3-all-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
blind = True
file1 = '../output/blind-metacal-8arcmincut-december/des-y3-2pt-500simcov-wCDM-blind-metacal.txt'
file2 = '../output/blind-metacal-8arcmincut-december/des-y3-2pt-map3-all-wCDM-blind-metacal.txt'

files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly_wcdm, desy3_joint_wcdm = chains[0], chains[1]
# Out:
# WARNING:root:outlier fraction 0.015748031496062992
# ../output/blind-metacal-8arcmincut-december/des-y3-2pt-500simcov-wCDM-blind-metacal.txt
# 9
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-december/des-y3-2pt-map3-all-wCDM-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
blind = True
file1 = '../output/blind-metacal-8arcmincut-december/des-y3-2pt-500simcov-wCDM-blind-metacal.txt'
file2 = '../output/blind-metacal-8arcmincut-december/des-y3-map3-all-wCDM-blind-metacal.txt'

files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly_wcdm, desy3_map3only_wcdm = chains[0], chains[1]
# Out:
# ../output/blind-metacal-8arcmincut-december/des-y3-2pt-500simcov-wCDM-blind-metacal.txt
# 9
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-december/des-y3-map3-all-wCDM-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
#now we do the wide priors
blind = True
file1 = '../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-blind-metacal-simcov.txt'
file2 = '../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-map3-all-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly_wp, desy3_joint_wp = chains[0], chains[1]
# Out:
# WARNING:root:outlier fraction 0.06813304721030043
# ../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-blind-metacal-simcov.txt
# 8
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-map3-all-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
#use as reference the 2pt with smaller prior
blind = True
file1 = '../output/blind-metacal-updatedcov/des-y3-2pt-blind-metacal-simcov.txt'
file2 = '../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-map3-all-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly, desy3_joint_wp = chains[0], chains[1]
# Out:
# ../output/blind-metacal-updatedcov/des-y3-2pt-blind-metacal-simcov.txt
# 8
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-map3-all-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
#wide priors too
blind = True
file1 = '../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-blind-metacal-simcov.txt'
file2 = '../output/blind-metacal-8arcmincut-news8prior/des-y3-map3-all-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly_wp, desy3_map3only_wp = chains[0], chains[1]
# Out:
# WARNING:root:outlier fraction 0.06813304721030043
# ../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-blind-metacal-simcov.txt
# 8
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-news8prior/des-y3-map3-all-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
#wide prior wcdm
blind = True
file1 = '../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-500simcov-wCDM-blind-metacal.txt'
file2 = '../output/blind-metacal-8arcmincut-news8prior/des-y3-map3-all-wCDM-blind-metacal.txt'

files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly_wcdm_wp, desy3_map3only_wcdm_wp = chains[0], chains[1]

file1 = '../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-500simcov-wCDM-blind-metacal.txt'
file2 = '../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-map3-all-wCDM-blind-metacal.txt'

files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly_wcdm_wp, desy3_joint_wcdm_wp = chains[0], chains[1]
# Out:
# ../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-500simcov-wCDM-blind-metacal.txt
# 9
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-news8prior/des-y3-map3-all-wCDM-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-500simcov-wCDM-blind-metacal.txt
# WARNING:root:outlier fraction 0.01753409407180629
# 9
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-news8prior/des-y3-2pt-map3-all-wCDM-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
#with reference to small prior version
blind = True
file1 = '../output/blind-metacal-8arcmincut-december/des-y3-2pt-500simcov-wCDM-blind-metacal.txt'
file2 = '../output/blind-metacal-8arcmincut-news8prior/des-y3-map3-all-wCDM-blind-metacal.txt'

files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly_wcdm, desy3_map3only_wcdm_wp = chains[0], chains[1]
# Out:
# ../output/blind-metacal-8arcmincut-december/des-y3-2pt-500simcov-wCDM-blind-metacal.txt
# 9
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-news8prior/des-y3-map3-all-wCDM-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
fom_2pt = utils.FoM_from_samples_names(desy3_2ptonly, ['om', 's8'])
all_fom = utils.FoM_from_samples_names(desy3_joint, ['om', 's8'])

print(fom_2pt)
print(all_fom)
print(all_fom/fom_2pt)
# Out:
# 796.8159863807681
# 1822.7808393524658
# 2.287580659157895

# %%
fom_2pt = utils.FoM_from_samples_names(desy3_2ptonly_wp, ['om', 's8'])
all_fom = utils.FoM_from_samples_names(desy3_joint_wp, ['om', 's8'])

print(fom_2pt)
print(all_fom)
print(all_fom/fom_2pt)
# Out:
# 706.0243510969472
# 1770.5102728282325
# 2.507718423702239

# %%
def chisq(sim):    
    like_array = sim['like']
    val = np.max(like_array)
    return(-2*val)

# %%
print(chisq(desy3_joint_wcdm))

# %%
print(chisq(all_sims1))
print(chisq(all_sims2))
print(chisq(all_sims3))
print(chisq(all_sims4))
print(chisq(all_sims5))
print(chisq(all_sims6))
print(chisq(all_sims7))
print(chisq(all_sims8))
print(chisq(all_sims9))
print(chisq(all_sims10))
print(chisq(all_sims11))
print(chisq(all_sims12))
print(chisq(all_sims13))
print(chisq(all_sims14))
print(chisq(all_sims15))
print(chisq(all_sims16))
print(chisq(all_sims17))
print(chisq(all_sims18))
print(chisq(all_sims19))
print(chisq(all_sims20))
print(chisq(all_sims21))
print(chisq(all_sims22))
print(chisq(all_sims23))
print(chisq(all_sims24))
print(chisq(all_sims25))
print(chisq(all_sims26))
print(chisq(all_sims27))
print(chisq(all_sims28))
print(chisq(all_sims29))
print(chisq(all_sims30))
print(chisq(all_sims31))
print(chisq(all_sims32))
print(chisq(all_sims33))
print(chisq(all_sims34))
print(chisq(all_sims35))
print(chisq(all_sims36))
print(chisq(all_sims37))
print(chisq(all_sims38))
print(chisq(all_sims39))
print(chisq(all_sims40))
print(chisq(all_sims41))
print(chisq(all_sims42))
print(chisq(all_sims43))
print(chisq(all_sims44))
print(chisq(all_sims45))
print(chisq(all_sims46))
print(chisq(all_sims47))
print(chisq(all_sims48))
print(chisq(all_sims49))
print(chisq(all_sims50))
print(chisq(desy3_joint))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create the numpy array
data = np.array([
    74.59148085889225, 66.36855940143082, 52.904099920624056, 70.94981627052228,
    74.91619352638668, 79.18946128130227, 80.06916919162884, 111.34660446283677,
    54.09817874062517, 77.30876238444023, 64.96373393291103, 76.65038277537897,
    65.87377224942784, 54.99662828123256, 76.33260176383743, 77.33079592963306,
    63.84341792624464, 53.197790726817374, 54.81667377755252, 65.22479186848221,
    69.78433995646547, 64.62113108299377, 82.90676405260396, 81.3357072709654,
    54.4129824276704, 91.11436736535275, 57.1591230277579, 61.32331620208133,
    68.7627763663463, 90.89453714508123, 94.9678376262527, 68.38631571484775,
    78.117944634383, 81.66105912846064, 62.63322607273055, 94.9568517520386,
    89.3705269663213, 60.475469068343855, 82.25086393531868, 74.39566993392094,
    94.73851672990548, 82.05183618170244, 78.56198152020626, 76.94194223948952,
    77.66939492342476, 60.9589101692851, 67.4904213521418, 76.51338958947889,
    79.90415234882502, 65.55435484999728
])

# Define the value for the red line
red_line_value = 69.68048967308282

# Plot the histogram
plt.hist(data, bins=15, color='darkolivegreen', edgecolor='black', alpha=0.7, label='Noisy sims')
plt.axvline(red_line_value, color='red', linestyle='--', linewidth=2, label='DESY3 blind chi2')
plt.xlim(40,120)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Chi2 values for noisy sims')

# Add legend
plt.legend()

# Show the plot
#plt.show()
plt.savefig("chi2_validation_Jan2025_Y3blind.pdf", dpi=500)

# %%
import matplotlib.pyplot as plt

# Initialize lists to store FoM values
fom_all_sims = []
fom_twpt_all_sims = []

# Compute FoM for all_sims1 to all_sims50
for i in range(1, 51):
    # Dynamically retrieve the variable using eval
    all_sims_var = eval(f"all_sims{i}")
    twpt_all_sims_var = eval(f"twpt_all_sims{i}")
    
    # Compute FoM and append to respective lists
    fom_all_sims.append(utils.FoM_from_samples_names(all_sims_var, ['om', 's8']))
    fom_twpt_all_sims.append(utils.FoM_from_samples_names(twpt_all_sims_var, ['om', 's8']))

    j=0
for i in range(len(fom_twpt_all_sims)):
    if fom_all_sims[i]>1822.7808393524642:
        j+=1
print(j/50)
# Plot histogram for FoM of all_sims
#plt.figure(figsize=(12, 6))
plt.hist(fom_all_sims, bins=15, color='c', alpha=0.7, edgecolor='black', label='noisy sims')
plt.axvline(1822.7808393524642, color='red', linestyle='--', linewidth=2, label='DESY3 blind')
plt.xlim(750,2750)
plt.xlabel('FoM')
plt.ylabel('Frequency')
plt.title('FoM values for joint chains')
plt.legend()
plt.show()
#plt.savefig("FoM_joint_validation_Jan2025_Y3blind.pdf", dpi=500)
# Out:
# 0.4

# %%
# Plot histogram for FoM of twpt_all_sims
j=0
for i in range(len(fom_twpt_all_sims)):
    if fom_twpt_all_sims[i]>796.8159863807681:
        j+=1
print(j/50)
#plt.figure(figsize=(12, 6))
plt.hist(fom_twpt_all_sims, bins=15, color='c', alpha=0.7, edgecolor='black', label='noisy sims')
plt.axvline(796.8159863807681, color='red', linestyle='--', linewidth=2, label='DESY3 blind')
plt.xlim(500,1600)
plt.xlabel('FoM')
plt.ylabel('Frequency')
plt.title('FoM values for 2pt-only chains')
plt.legend()
#plt.savefig("FoM_2pcf_validation_Jan2025_Y3blind.pdf", dpi=500)
plt.show()

# %%
mean_fom_all_sims = np.mean(fom_all_sims)
mean_fom_twpt_all_sims = np.mean(fom_twpt_all_sims)

# Print the results
print(f"Mean FoM for all_sims: {mean_fom_all_sims}")
print(f"Mean FoM for twpt_all_sims: {mean_fom_twpt_all_sims}")

print(mean_fom_all_sims/mean_fom_twpt_all_sims)

# %%
# Compute the ratios between corresponding entries
ratios = [fom_all_sims[i] / fom_twpt_all_sims[i] for i in range(len(fom_all_sims))]
print(ratios)

# Plot the histogram of the ratios
plt.figure(figsize=(12, 6))
plt.hist(ratios, bins=10, color='darkolivegreen', alpha=0.7, edgecolor='black', label='Ratios of FoM (all_sims / twpt_all_sims)')
plt.xlabel('Ratio')
plt.ylabel('Frequency')
plt.title('Histogram of Ratios of FoM values')
plt.legend()
plt.show()

# Print the mean ratio
mean_ratio = np.mean(ratios)
print(f"Mean ratio (all_sims / twpt_all_sims): {mean_ratio}")
# Out:
# [2.1281753459709427, 1.689603914920541, 1.5545967626404988, 1.603280073429498, 2.446803275474074, 1.4001128397701406, 1.9347219821120176, 1.7948703902594212, 2.6989068126802134, 1.3317652078732534, 2.215006526341612, 2.3663885040854944, 2.09360368626746, 2.247189122250968, 1.8757267927342731, 1.8625425951074601, 1.9859436463469127, 1.528468898375478, 2.1068003277080574, 1.8658163332015916, 1.7150173099807078, 1.9016434166266056, 1.6398562835664887, 1.5667453196847512, 1.5777643259247727, 2.535268305866768, 1.5275027556960845, 1.5832941131663887, 1.8962120323897347, 2.120785294843924, 2.152471053826181, 1.4707040053571712, 1.1796778550407474, 2.1944640115545133, 2.1603205534977885, 1.3005278290734443, 1.4857184360586995, 1.572884273911085, 1.3452206043784385, 2.1055796406543945, 1.5404852065127836, 1.2961352946124904, 1.2730203737669048, 1.2443075437319011, 2.2311249327576106, 1.706042329694256, 1.328810732223213, 1.2717269363536174, 1.7274832398524032, 1.3928617093563689]
# ...

# %%
def extract_diff_s8_blind():
    blind = False
    sim_2pt = desy3_2ptonly
    sim = desy3_joint
    s8 = sim.getMeans()[4]
    s8_2pt = sim_2pt.getMeans()[4]
    diff = s8 - s8_2pt
    return(diff)

print(extract_diff_s8_blind())

# %%
def extract_diff_om_blind():
    blind = False
    sim_2pt = desy3_2ptonly
    sim = desy3_joint
    om = sim.getMeans()[0]
    om_2pt = sim_2pt.getMeans()[0]
    diff = om - om_2pt
    return(diff)

print(extract_diff_om_blind())

# %%
def extract_diff_s8(num):
    # Dynamically retrieve the appropriate all_sims and twpt_all_sims instances
    sim = eval(f"all_sims{num}")
    sim_2pt = eval(f"twpt_all_sims{num}")
    
    # Compute the difference in s8 values
    s8 = sim.getMeans()[4]
    s8_2pt = sim_2pt.getMeans()[4]
    diff = s8 - s8_2pt
    
    return diff

# %%
# Compute differences for all 50 simulations
s8_differences = [extract_diff_s8(num) for num in range(1, 51)]

# Plot histogram of the differences
#plt.figure(figsize=(12, 6))
plt.hist(s8_differences, bins=15, color='orange', alpha=0.7, edgecolor='black', label='noisy data')
plt.axvline(x=0.029358197928624437, color='blue', linestyle='--', label='DESY3 blind')
plt.xlim(-0.05,0.05)
plt.xlabel('Difference in s8')
plt.ylabel('Frequency')
plt.title('s8 difference between 2pt-only and joint chains')
plt.legend()
#plt.show()

# Compute and print the mean difference
mean_diff = np.mean(s8_differences)
print(f"Mean difference in s8: {mean_diff}")
plt.show()
#plt.savefig("s8diff_validation_Jan2025_Y3blind.pdf", dpi=500)

# %%
# Compute differences for all 50 simulations
om_differences = [extract_diff_om(num) for num in range(1, 51)]

# Plot histogram of the differences
#plt.figure(figsize=(12, 6))
plt.hist(om_differences, bins=15, color='orange', alpha=0.7, edgecolor='black', label='noisy data')
plt.axvline(x=-0.07878654137397974, color='blue', linestyle='--', label='DESY3 blind')
plt.xlim(-0.09,0.05)
plt.xlabel('Difference in s8')
plt.ylabel('Frequency')
plt.title('omega_m difference between 2pt-only and joint chains')
plt.legend()
#plt.show()

# Compute and print the mean difference
mean_diff = np.mean(om_differences)
print(f"Mean difference in om: {mean_diff}")
#plt.show()
plt.savefig("om_shift_Y3_blind_Jan2025.pdf", dpi=500)

# %%
# Define the function to extract differences in omega_m
def extract_diff_om(num):
    # Dynamically retrieve the appropriate all_sims and twpt_all_sims instances
    sim = eval(f"all_sims{num}")
    sim_2pt = eval(f"twpt_all_sims{num}")
    
    # Compute the difference in omega_m values
    om = sim.getMeans()[0]
    om_2pt = sim_2pt.getMeans()[0]
    diff = om - om_2pt
    
    return diff

# %%
# Compute differences for all 50 simulations
s8_differences = [extract_diff_s8(num) for num in range(1, 51)]
om_differences = [extract_diff_om(num) for num in range(1, 51)]

# Plot a 2D scatter plot
plt.figure(figsize=(8, 6))
s8_diff_ref = 0.029358197928624437
om_diff_ref = -0.07878654137397974
plt.scatter(om_diff_ref, s8_diff_ref, color='blue', s=100, label='Y3 blind')  # Add blue point
plt.scatter(om_differences, s8_differences, color='r', alpha=0.7, label='Noisy sims')
plt.axhline(y=0, color='gray', linestyle='--', linewidth=2, label='s8 Difference = 0')
plt.axvline(x=0, color='gray', linestyle='--', linewidth=2, label='omega_m Difference = 0')
plt.xlabel('Difference in $\Omega_m$')
plt.ylabel('Difference in $s_8$')
plt.title('2D Scatter Plot of Differences in $\Omega_m$ and $s_8$')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
#plt.show()
plt.savefig("../plots/2d_shifts_y3_blind_Jan2025.pdf", dpi=500)

# Print means for reference
mean_s8_diff = np.mean(s8_differences)
mean_om_diff = np.mean(om_differences)
print(f"Mean difference in s8: {mean_s8_diff}")
print(f"Mean difference in omega_m: {mean_om_diff}")

# %%
import numpy as np

def compute_peak_distance(i, param1='om', param2='s8'):
    """
    Compute the 2D Euclidean distance between the peaks of the 2D marginalized posteriors
    for the i-th chain of all_sims and twpt_all_sims.

    Parameters:
    - i: Index (1-based) of the chain to analyze.
    - param1: First parameter for the 2D posterior (default: 'omegam').
    - param2: Second parameter for the 2D posterior (default: 's8').

    Returns:
    - distance: The 2D Euclidean distance between the peaks of the posteriors.
    """
    def get_peak_of_posterior(mc_sample, param1, param2):
        # Get the 2D marginalized posterior
        density = mc_sample.get2DDensityGridData(param1, param2)
        x, y = density.x, density.y  # Grid values for parameters
        prob = density.P            # 2D posterior probabilities

        # Find the peak (maximum) of the posterior
        max_idx = np.unravel_index(np.argmax(prob), prob.shape)
        peak_x = x[max_idx[0]]
        peak_y = y[max_idx[1]]
        
        return peak_x, peak_y

    # Dynamically get the variables from globals
    all_sims_var = globals()[f'all_sims{i}']
    twpt_all_sims_var = globals()[f'twpt_all_sims{i}']

    # Compute the peaks for both chains
    peak1 = get_peak_of_posterior(all_sims_var, param1, param2)
    peak2 = get_peak_of_posterior(twpt_all_sims_var, param1, param2)

    # Compute the 2D Euclidean distance
    distance = np.sqrt((peak1[0] - peak2[0])**2 + (peak1[1] - peak2[1])**2)
    
    return distance

# %%
import matplotlib.pyplot as plt

# Compute distances for all chains from 1 to 50
distances = []
indices = range(1, 51)  # 1 to 50

for i in indices:
    try:
        distance = compute_peak_distance(i)
        print(distance)
        distances.append(distance)
    except KeyError:
        print(f"Chain {i} not found. Skipping...")

# Filter out None values if any chains were missing
valid_distances = [d for d in distances if d is not None]

# Create a histogram
plt.figure(figsize=(8, 6))
plt.hist(valid_distances, bins=15, color='darkorange', edgecolor='black', alpha=0.7, label='noisy sims')
reference_value = 0.08772572685725444
plt.axvline(reference_value, color='red', linestyle='--', linewidth=1.5, label='Y3 blind')
plt.xlabel('2D Distance')
plt.ylabel('Frequency')
plt.title('Histogram of 2D (omega_m and s8) Distance Between Peaks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
#plt.savefig("../plots/2d_distance_om_and_s8_y3blind.pdf", dpi=500)

# %%
import matplotlib.pyplot as plt

# Compute distances for all chains from 1 to 50
distances = []
indices = range(1, 51)  # 1 to 50

for i in indices:
    try:
        distance = compute_peak_distance(i, 's8', 'a1')
        distances.append(distance)
    except KeyError:
        print(f"Chain {i} not found. Skipping...")

# Filter out None values if any chains were missing
valid_distances = [d for d in distances if d is not None]

# Create a histogram
plt.figure(figsize=(8, 6))
plt.hist(valid_distances, bins=15, color='darkorange', edgecolor='black', alpha=0.7, label='noisy sims')
reference_value = 1.5343407380862144
plt.axvline(reference_value, color='red', linestyle='--', linewidth=1.5, label='Y3 blind')
plt.xlabel('2D Euclidean Distance')
plt.ylabel('Frequency')
plt.title('Histogram of 2D (s8 and A1) Distance Between Peaks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt

# Compute distances for all chains from 1 to 50
distances = []
indices = range(1, 51)  # 1 to 50

for i in indices:
    try:
        distance = compute_peak_distance(i, 'om', 'a1')
        distances.append(distance)
    except KeyError:
        print(f"Chain {i} not found. Skipping...")

# Filter out None values if any chains were missing
valid_distances = [d for d in distances if d is not None]

# Create a histogram
plt.figure(figsize=(8, 6))
plt.hist(valid_distances, bins=15, color='darkorange', edgecolor='black', alpha=0.7, label='noisy sims')
reference_value = 2.24277310998795
plt.axvline(reference_value, color='red', linestyle='--', linewidth=1.5, label='Y3 blind')
plt.xlabel('2D Euclidean Distance')
plt.ylabel('Frequency')
plt.title('Histogram of 2D (omega_m and A1) Distance Between Peaks')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([twpt_all_sims6, all_sims6], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=['2pt', '2pt+map3'], legend_loc='upper right', 
    contour_colors=['gray', 'red'], markers={'om':0.26, 's8':0.782})
plt.show()

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([desy3_2ptonly, desy3_joint], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=['2pt', '2pt+map3'], legend_loc='upper right', 
    contour_colors=['gray', 'red'])
plt.show()

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([desy3_2ptonly, desy3_map3only, desy3_joint, desy3_2ptonly_wp, desy3_map3only_wp, desy3_joint_wp], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=['2pt', 'map3', '2pt+map3', '2pt (wp)', 'map3 (wp)', '2pt+map3 (wp)'], legend_loc='upper right', 
    contour_colors=['gray','green', 'red', 'gray','green', 'red'], linestyles=['-', '-', '-', ':', ':', ':'])
plt.show()
#plt.savefig("../plots/desy3_blind_Jan2025.pdf", dpi=500)

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([desy3_2ptonly2, desy3_map3only, desy3_joint], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=['2pt', 'map3', '2pt+map3'], legend_loc='upper right', 
    contour_colors=['gray','green', 'red'])
plt.show()

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([desy3_2ptonly_wcdm, desy3_map3only_wcdm, desy3_joint_wcdm], ['om', 's8', 'w0', 'sig8', 'a1'], filled=False, \
    legend_labels=['2pt', 'map3', '2pt+map3'], legend_loc='upper right', 
    contour_colors=['gray','green', 'red'])
#plt.show()
plt.savefig("wCDM_blind_metacal.pdf")

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([desy3_2ptonly_wcdm_wp, desy3_map3only_wcdm_wp, desy3_joint_wcdm_wp], ['om', 's8', 'w0', 'sig8', 'a1'], filled=False, \
    legend_labels=['2pt', 'map3', '2pt+map3'], legend_loc='upper right', 
    contour_colors=['gray','green', 'red'])
plt.show()
#plt.savefig("wCDM_blind_metacal.pdf")

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([desy3_2ptonly_wcdm, desy3_map3only_wcdm, desy3_joint_wcdm,desy3_2ptonly_wcdm_wp, desy3_map3only_wcdm_wp, desy3_joint_wcdm_wp], ['om', 's8', 'w0', 'sig8', 'a1'], filled=False, \
    legend_labels=['2pt', 'map3', '2pt+map3', '2pt (wp)', 'map3 (wp)', '2pt+map3 (wp)'], legend_loc='upper right', 
    contour_colors=['gray','green', 'red', 'gray','green', 'red'])
plt.show()

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([desy3_map3only_wcdm, desy3_map3only_wcdm_wp, ], ['om', 's8', 'w0', 'sig8', 'a1'], filled=False, \
    legend_labels=['map3 (tighter s8 prior)', 'map3 (wider s8 prior)'], legend_loc='upper right', 
    contour_colors=['green', 'red'])
plt.savefig('prior_diff_chains_wcdm.pdf', dpi=500)
#plt.show()

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([desy3_map3only, desy3_map3only_wp, ], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=['map3 (tighter s8 prior)', 'map3 (wider s8 prior)'], legend_loc='upper right', 
    contour_colors=['green', 'red'])
plt.savefig('prior_diff_chains_lcdm.pdf', dpi=500)
#plt.show()

# %%
fom_2pt = utils.FoM_from_samples_names(desy3_2ptonly_wcdm, ['om', 's8'])
all_fom = utils.FoM_from_samples_names(desy3_joint_wcdm, ['om', 's8'])

print(fom_2pt)
print(all_fom)
print(all_fom/fom_2pt)
# Out:
# 558.3693965791025
# 984.4528540335274
# 1.7630852623099713

# %%
fom_2pt = utils.FoM_from_samples_names(desy3_2ptonly_wcdm, ['w0', 's8'])
all_fom = utils.FoM_from_samples_names(desy3_joint_wcdm, ['w0', 's8'])

print(fom_2pt)
print(all_fom)
print(all_fom/fom_2pt)
# Out:
# 147.6273674756103
# 210.1207225245267
# 1.4233182242394251

# %%
fom_2pt = utils.FoM_from_samples_names(desy3_2ptonly_wcdm, ['a1'])
all_fom = utils.FoM_from_samples_names(desy3_joint_wcdm, ['a1'])

print(fom_2pt)
print(all_fom)
print(all_fom/fom_2pt)
# Out:
# 2.2973159184954963
# 2.00929426544871
# 0.874626884910365

# %%
fom_2pt = utils.FoM_from_samples_names(desy3_2ptonly_wcdm, ['w0'])
all_fom = utils.FoM_from_samples_names(desy3_joint_wcdm, ['w0'])

print(fom_2pt)
print(all_fom)
print(all_fom/fom_2pt)
# Out:
# 2.802415979510637
# 3.0753522908077726
# 1.0973932183132913

# %%
fom_2pt = utils.FoM_from_samples_names(desy3_2ptonly_wcdm, ['s8'])
all_fom = utils.FoM_from_samples_names(desy3_joint_wcdm, ['s8'])

print(fom_2pt)
print(all_fom)
print(all_fom/fom_2pt)
# Out:
# 37.011283728071504
# 36.0693277110399
# 0.974549490799824

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([desy3_2ptonly, desy3_joint], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=['2pt', '2pt+map3'], legend_loc='upper right', 
    contour_colors=['gray', 'red'])
plt.show()
#plt.savefig("desy3_joint_blind_analysis_2025.pdf")

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([twpt_all_sims, twpt_all_sims_400, all_sims, all_sims_400], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=[r'$\xi_{\pm}$ (500 sims)', r'$\xi_{\pm}$ (400 sims)',r'$\xi_{\pm}$+$\langle M_{\rm ap}^3\rangle$ (500 sims)', r'$\xi_{\pm}$+$\langle M_{\rm ap}^3\rangle$ (400 sims)'], legend_loc='upper right', 
    contour_colors=['blue', 'blue', 'green', 'green'], ls=['-', '--', '-', '--'], markers={'om':0.26, 's8':0.782})
plt.show()

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([twopt_meas, all_sims, map3_all_sims], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=['2pt', '2pt+map3', 'map3'], legend_loc='upper right', 
    contour_colors=['gray', 'red', 'green'], markers={'om':0.26, 's8':0.782})
#plt.savefig("Oct30_sim_analysis_cosmogridcutcov.pdf")
plt.show()

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([twopt_meas, twpt_all_sims, all_sims], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=['2pt(meas)', '2pt(theo)', '2pt+map3'], legend_loc='upper right', 
    contour_colors=['gray', 'blue', 'red'])
#plt.savefig("Oct30_sim_analysis_cosmogridcutcov.pdf")
plt.show()

# %%
#load covariances w/ 500 sims and 400 sims
from astropy.io import fits

cov500 = fits.open("../data/covariance/xip_xim_map3_covariance_8ARCMINCUT_31Oct24.fits")
cov400 = fits.open("../data/covariance/xip_xim_map3_covariance_8ARCMINCUT_400SIMCOV_9Nov.fits")

mycov500 = cov500[1].data[400:,:][:,400:]
mycov400 = cov400[1].data[400:,:][:,400:]

corr400 = mycov400 / np.sqrt(np.outer(np.diag(mycov400), np.diag(mycov400)))
corr500 = mycov500 / np.sqrt(np.outer(np.diag(mycov500), np.diag(mycov500)))

# Compute the Frobenius norm difference
frobenius_diff = np.linalg.norm(mycov400 - mycov500, 'fro')
print(frobenius_diff)

# Create a combined matrix with upper triangle from corr500 and lower triangle from corr400
combined_corr = np.tril(corr500) + np.triu(corr400, k=1)
#combined_corr = np.tril(corr500)
# Plot the combined correlation matrix
fig, ax = plt.subplots(figsize=(8, 8))
#cax = ax.matshow(combined_corr, cmap='coolwarm')

cax = ax.imshow(combined_corr, cmap='coolwarm', origin='lower')

for v in range(20):
    ax.axhline(v*4, color='k', lw=0.1)
    ax.axvline(v*4, color='k', lw=0.1)
# label
labels = []
for i in range(4):
    for j in range(i, 4):
        for k in range(j, 4):
            labels.append(f'{i+1}{j+1}{k+1}')
ax.set_xticks(4*np.arange(20)+2, labels, rotation=90)
ax.set_yticks(4*np.arange(20)+2, labels)

plt.colorbar(cax)

# Add titles and Frobenius norm difference annotation
#ax.set_title("Combined Correlation Matrix\nUpper: mycov500, Lower: mycov400", pad=20)
plt.show()
#plt.savefig("../plots/combined_corr_upper500sims_lower400sims.pdf", dpi=500)

# %%
#Compute the signal-to-noise: total and per bin

def total_signal_to_noise(data_vector, covariance_matrix):
    """Computes the total signal-to-noise ratio for the full data vector and covariance matrix."""
    inv_cov = np.linalg.inv(covariance_matrix)
    sn_total_squared = data_vector.T @ inv_cov @ data_vector
    return np.sqrt(sn_total_squared)

def sectionwise_signal_to_noise(data_vector, covariance_matrix, section_size=4):
    """Computes the signal-to-noise ratio for each section of the data vector and covariance matrix."""
    num_sections = len(data_vector) // section_size
    sn_sections = []
    
    for i in range(num_sections):
        start_idx = i * section_size
        end_idx = start_idx + section_size
        
        data_section = data_vector[start_idx:end_idx]
        cov_section = covariance_matrix[start_idx:end_idx, start_idx:end_idx]
        
        inv_cov_section = np.linalg.inv(cov_section)
        sn_section_squared = data_section.T @ inv_cov_section @ data_section
        sn_sections.append(np.sqrt(sn_section_squared))
    
    return sn_sections

# %%
def modified_signal_to_noise(data_vector, covariance_matrix):
    """Computes the signal-to-noise ratio after removing the first element of each 4-element sequence."""
    # Indices to keep (i.e., remove 0, 4, 8, 12, ..., 76)
    indices_to_keep = [i for i in range(len(data_vector)) if i % 4 != 0]
    
    # Reduced data vector and covariance matrix
    reduced_data_vector = data_vector[indices_to_keep]
    reduced_covariance_matrix = covariance_matrix[np.ix_(indices_to_keep, indices_to_keep)]
    
    # Compute S/N
    inv_reduced_cov = np.linalg.inv(reduced_covariance_matrix)
    sn_squared = reduced_data_vector.T @ inv_reduced_cov @ reduced_data_vector
    return np.sqrt(sn_squared)

def smallscale_signal_to_noise(data_vector, covariance_matrix):
    
    indices_to_keep = [i for i in range(len(data_vector)) if i % 4 == 0]
    reduced_data_vector = data_vector[indices_to_keep]
    reduced_covariance_matrix = covariance_matrix[np.ix_(indices_to_keep, indices_to_keep)]
    inv_reduced_cov = np.linalg.inv(reduced_covariance_matrix)
    sn_squared = reduced_data_vector.T @ inv_reduced_cov @ reduced_data_vector
    return np.sqrt(sn_squared)

# %%
from astropy.io import fits

my_cov_data_file = fits.open('../data/dv/sim_map3-desy3c_cosmogridcutcov.fits')
my_cov_data_file_2 = fits.open('../data/dv/meas_map3-ave-cosmogrid_weighted.fits')
my_sim_data_file = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-30Oct24-nocut-b.fits')
my_avg_data_file = fits.open('../data/dv/meas_map3-ave-cosmogrid_weighted.fits') #avg data with no cut
my_sim_data_file_2 = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-30Oct24-5arcmincut.fits') #with 5arcmin cut
my_sim_data_file_6arcmin = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-30Oct24-6arcmincut.fits') #with 6arcmin cut
my_sim_data_file_8arcmin = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-30Oct24-8arcmincut.fits') #with 8arcmin cut
my_sim_data_file_3 = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-30Oct24-11arcmincut.fits') #with 11arcmin cut

my_sim_data_file_tent = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-1Nov24-6arcmincut-tentativemap3v.fits')
my_sim_data_file_tent2 = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-2Nov24-8arcmincut-tentativemap3v2.fits')
my_sim_data_file_tent3 = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-2Nov24-8arcmincut-tentativemap3v3.fits')

my_sim_data_file_8arcmin_cmg = fits.open('../data/dv/sim_map3-cosmoCosmogrid-6Nov24-8arcmincut-WITH_COV.fits')

#my_sim_data = my_sim_data_file[1].data #sim data with no cut
#my_sim_data = my_avg_data_file[1].data #avg data with no cut
#my_sim_data = my_sim_data_file_2[1].data #sim data 5arcmin cut
#my_sim_data = my_sim_data_file_6arcmin[1].data #sim data 6arcmin cut
#my_sim_data = my_sim_data_file_8arcmin[1].data #sim data 8arcmin cut
#my_sim_data = my_sim_data_file_3[1].data #sim data 11arcmin cut
#my_sim_data = np.load("../data/dv/map3_average_5arcmincut_maxn100.npy") #avg data with 5arcmin cut

#my_sim_data = my_sim_data_file_tent[1].data #sim data 6arcmin cut and 9,17,28,43 map3 vals
#my_sim_data = my_sim_data_file_tent2[1].data #sim data 8arcmin cut and 8,16,28,45 map3 vals
#my_sim_data = my_sim_data_file_tent3[1].data #sim data 8arcmin cut and 6,12,24,40 map3 vals

my_sim_data = my_sim_data_file_8arcmin_cmg[1].data #sim data 8arcmin cut at cosmogrid cosmology

#my_cut_cov = my_cov_data_file[2].data #cov with 11arcmin scalecut
my_cut_cov = np.load("../data/covariance/map3_covariance_8arcmincut_maxn100.npy") #cov with 8 arcmin scalecut
#my_cut_cov = np.load("../data/covariance/map3_covariance_6arcmincut_maxn100.npy") #cov with 6 arcmin scalecut
#my_cut_cov = np.load("../data/covariance/map3_covariance_5arcmincut_maxn100.npy") #cov with 5arcmin scalecut
#my_cut_cov = my_cov_data_file_2[2].data #cov with no scalecut

#my_cut_cov = np.load("../data/covariance/map3_covariance_6arcmincut_tentativemap3v.npy") #cov with 6arcmin cut and 9,17,28,43 map3 vals
#my_cut_cov = np.load("../data/covariance/map3_covariance_8arcmincut_tentativemap3v2.npy") #cov with 8arcmin cut and 8,16,28,45 map3 vals
#my_cut_cov = np.load("../data/covariance/map3_covariance_8arcmincut_tentativemap3v3.npy") #cov with 8arcmin cut and 6,12,24,40 map3 vals

data_tot = np.zeros(80)
for i in range(80):
    data_tot[i] = my_sim_data[i][6]
#data_tot = my_sim_data
cov_tot = np.array(my_cut_cov)

# %%
print(my_sim_data)

# %%
print(total_signal_to_noise(data_tot,cov_tot))

# %%
print(modified_signal_to_noise(data_tot,cov_tot))

# %%
print(smallscale_signal_to_noise(data_tot,cov_tot))

# %%
print(sectionwise_signal_to_noise(data_tot,cov_tot))

# %%
#Compare plots of sim data with different cuts
def plot_data_vector_sections(data_vectors, covariance_matrices, section_index):
    """Plots the specified section of each data vector with error bars, labeled by redshift bin combination.
    
    Args:
        data_vectors (list of np.ndarray): List of data vectors.
        covariance_matrices (list of np.ndarray): List of covariance matrices.
        section_index (int): Index specifying which section (0 to 19) to plot.
    """
    # Validate inputs
    assert 0 <= section_index < 20, "section_index must be between 0 and 19."
    assert len(data_vectors) == len(covariance_matrices), "Data vectors and covariance matrices must have the same length."

    # Define the redshift bin combinations
    redshift_bins = [
        "111", "112", "113", "114", "122", "123", "124", "133", "134", "144",
        "222", "223", "224", "233", "234", "244", "333", "334", "344", "444"
    ]
    
    # Define the x-axis values and small shifts for visualization
    x_nominal = np.array([7, 14, 25, 40])  # Nominal x-axis values in arcminutes
    shift_values = np.linspace(-0.8, 0.8, len(data_vectors))  # Small shifts for each line

    # Plotting each data vector section with error bars
    plt.figure(figsize=(10, 6))
    
    for i, (data_vector, covariance_matrix) in enumerate(zip(data_vectors, covariance_matrices)):
        # Extract the specified section of the data vector and covariance matrix
        start_idx = section_index * 4
        end_idx = start_idx + 4
        data_section = data_vector[start_idx:end_idx]
        cov_section = covariance_matrix[start_idx:end_idx, start_idx:end_idx]

        # Compute errors as the square root of the diagonal of the covariance matrix section
        errors = np.sqrt(np.diag(cov_section))

        # Apply a small shift to the x-axis values
        x_shifted = x_nominal + shift_values[i]

        # Plot with error bars
        plt.errorbar(x_shifted, x_nominal**4*data_section, yerr=x_nominal**4*errors, fmt='o', label=f'Data Vector {i+1}')
    
    # Labeling
    #plt.yscale("log")
    plt.xlabel(r'$\theta$ (arcminutes)')
    plt.ylabel(r'$\theta^4 \times M_{ap}^3(\theta)$')
    plt.title(f'Redshift Bin Combination {redshift_bins[section_index]} of Data Vectors')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
my_cov_data_file = fits.open('../data/dv/sim_map3-desy3c_cosmogridcutcov.fits')
my_cov_data_file_2 = fits.open('../data/dv/meas_map3-ave-cosmogrid_weighted.fits')
my_sim_data_file = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-30Oct24-nocut-b.fits')
my_avg_data_file = fits.open('../data/dv/meas_map3-ave-cosmogrid_weighted.fits') #avg data with no cut
my_sim_data_file_2 = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-30Oct24-5arcmincut.fits') #with 5arcmin cut
my_sim_data_file_6arcmin = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-30Oct24-6arcmincut.fits') #with 6arcmin cut
my_sim_data_file_8arcmin = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-30Oct24-8arcmincut.fits') #with 8arcmin cut
my_sim_data_file_3 = fits.open('../data/dv/sim_map3_emu-NLA-cosmoDESY3-30Oct24-11arcmincut.fits') #with 11arcmin cut

my_sim_data0 = my_sim_data_file[1].data #sim data with no cut
my_sim_data5 = my_sim_data_file_2[1].data #sim data 5arcmin cut
my_sim_data6 = my_sim_data_file_6arcmin[1].data #sim data 6arcmin cut
my_sim_data8 = my_sim_data_file_8arcmin[1].data #sim data 8arcmin cut
my_sim_data11 = my_sim_data_file_3[1].data #sim data 11arcmin cut
my_sim_data_AVG = my_avg_data_file[1].data #avg data

my_cut_cov11 = my_cov_data_file[2].data #cov with 11arcmin scalecut
my_cut_cov8 = np.load("../data/covariance/map3_covariance_8arcmincut_maxn100.npy") #cov with 8 arcmin scalecut
my_cut_cov6 = np.load("../data/covariance/map3_covariance_6arcmincut_maxn100.npy") #cov with 6 arcmin scalecut
my_cut_cov5 = np.load("../data/covariance/map3_covariance_5arcmincut_maxn100.npy") #cov with 5arcmin scalecut
my_cut_cov0 = my_cov_data_file_2[2].data #cov with no scalecut

data_tot0 = np.zeros(80)
data_tot5 = np.zeros(80)
data_tot6 = np.zeros(80)
data_tot8 = np.zeros(80)
data_tot11 = np.zeros(80)
data_tot_AVG = np.zeros(80)

for i in range(80):
    data_tot0[i] = my_sim_data0[i][6]
    data_tot5[i] = -my_sim_data5[i][6]
    data_tot6[i] = -my_sim_data6[i][6]
    data_tot8[i] = -my_sim_data8[i][6]
    data_tot11[i] = -my_sim_data11[i][6]
    data_tot_AVG[i] = my_sim_data_AVG[i][6]

cov_tot0 = np.array(my_cut_cov0)
cov_tot5 = np.array(my_cut_cov5)
cov_tot6 = np.array(my_cut_cov6)
cov_tot8 = np.array(my_cut_cov8)
cov_tot11 = np.array(my_cut_cov11)

data_arr = [data_tot0, data_tot5, data_tot6, data_tot8, data_tot11]
cov_arr = [cov_tot0, cov_tot5, cov_tot6, cov_tot8, cov_tot11]
plot_data_vector_sections(data_arr, cov_arr, 19)

# %%
data_arr = [data_tot0, data_tot_AVG]
cov_arr = [cov_tot0, cov_tot0]
plot_data_vector_sections(data_arr, cov_arr, 15)

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.triangle_plot([twopoint_wCDM, map3_wCDM, all_sims_wCDM], ['om', 's8', 'w0'], filled=False, \
    legend_labels=['2pt only', 'map3 only', '2pt+map3'], legend_loc='upper right', 
    contour_colors=['green', 'red', 'blue'])
plt.show()

# %%
fom_2pt_1 = utils.FoM_from_samples_names(twpt_all_sims1, ['om', 's8'])
joint_fom_1 = utils.FoM_from_samples_names(all_sims1, ['om', 's8'])
fom_2pt_2 = utils.FoM_from_samples_names(twpt_all_sims2, ['om', 's8'])
joint_fom_2 = utils.FoM_from_samples_names(all_sims2, ['om', 's8'])
fom_2pt_3 = utils.FoM_from_samples_names(twpt_all_sims3, ['om', 's8'])#
joint_fom_3 = utils.FoM_from_samples_names(all_sims3, ['om', 's8'])
fom_2pt_4 = utils.FoM_from_samples_names(twpt_all_sims4, ['om', 's8'])
joint_fom_4 = utils.FoM_from_samples_names(all_sims4, ['om', 's8'])
fom_2pt_5 = utils.FoM_from_samples_names(twpt_all_sims5, ['om', 's8'])
joint_fom_5 = utils.FoM_from_samples_names(all_sims5, ['om', 's8'])
fom_2pt_6 = utils.FoM_from_samples_names(twpt_all_sims6, ['om', 's8'])
joint_fom_6 = utils.FoM_from_samples_names(all_sims6, ['om', 's8'])


print(fom_2pt_1, joint_fom_1)
print(joint_fom_1/fom_2pt_1)
print(fom_2pt_2, joint_fom_2)
print(joint_fom_2/fom_2pt_2)
print(fom_2pt_3, joint_fom_3)
print(joint_fom_3/fom_2pt_3)
print(fom_2pt_4, joint_fom_4)
print(joint_fom_4/fom_2pt_4)
print(fom_2pt_5, joint_fom_5)
print(joint_fom_5/fom_2pt_5)
print(fom_2pt_6, joint_fom_6)
print(joint_fom_6/fom_2pt_6)

# %%
def covmatparams(mcchain, index=0.5):#manual check of the det(cov)
    # Assuming twpt_all_sims contains samples and weights is the corresponding weight array
    omega_m_samples = mcchain['om']
    sigma_8_samples = mcchain['sig8']*(mcchain['om']/0.3)**index
    weights = mcchain.weights

    # Step 1: Calculate the weighted mean for each parameter
    mean_omega_m = np.sum(weights * omega_m_samples) / np.sum(weights)
    mean_sigma_8 = np.sum(weights * sigma_8_samples) / np.sum(weights)

    # Step 2: Calculate deviations from the weighted mean
    delta_omega_m = omega_m_samples - mean_omega_m
    delta_sigma_8 = sigma_8_samples - mean_sigma_8

    # Step 3: Calculate the weighted covariance elements
    cov_omega_m_omega_m = np.sum(weights * delta_omega_m * delta_omega_m) / np.sum(weights)
    cov_sigma_8_sigma_8 = np.sum(weights * delta_sigma_8 * delta_sigma_8) / np.sum(weights)
    cov_omega_m_sigma_8 = np.sum(weights * delta_omega_m * delta_sigma_8) / np.sum(weights)

    # Step 4: Construct the 2x2 weighted covariance matrix
    weighted_cov_matrix = np.array([[cov_omega_m_omega_m, cov_omega_m_sigma_8],
                                [cov_omega_m_sigma_8, cov_sigma_8_sigma_8]])

    #print("Weighted 2x2 Covariance Matrix:")
    #print(weighted_cov_matrix)
    #print(np.linalg.det(weighted_cov_matrix))
    #print(1/(np.sqrt(np.linalg.det(weighted_cov_matrix))))
    return(1/(np.sqrt(np.linalg.det(weighted_cov_matrix))))

# %%
def covmap_improv(mcchain1, mcchain2, index=0.5):
    fom1 = covmatparams(mcchain1, index)
    fom2 = covmatparams(mcchain2, index)
    return(fom2/fom1)

# %%
covmatparams(twpt_all_sims)
covmatparams(twpt_all_sims_400)
covmatparams(all_sims)
covmatparams(all_sims_400)

# %%
fom_2pt = utils.FoM_from_samples_names(twpt_all_sims, ['s8'])
joint_fom = utils.FoM_from_samples_names(all_sims, ['s8'])

fom_2pt_400 = utils.FoM_from_samples_names(twpt_all_sims_400, ['s8'])
joint_fom_400 = utils.FoM_from_samples_names(all_sims_400, ['s8'])

print(fom_2pt)
print(joint_fom)
print(fom_2pt_400)
print(joint_fom_400)

# %%
# Get parameter names
param_names_all_sims = all_sims.getParamNames().names  # Correctly get the list of parameter names as strings

# Marginalized means
mean_all_sims = all_sims.getMeans()

# Marginalized standard deviations (uncertainties)
sigma_all_sims = [all_sims.std([param]) for param in param_names_all_sims]

# Repeat for the other chains
param_names_map3_all_sims = map3_all_sims.getParamNames().names
mean_map3_all_sims = map3_all_sims.getMeans()
sigma_map3_all_sims = [map3_all_sims.std([param]) for param in param_names_map3_all_sims]

param_names_twpt_all_sims = twpt_all_sims.getParamNames().names
mean_twpt_all_sims = twpt_all_sims.getMeans()
sigma_twpt_all_sims = [twpt_all_sims.std([param]) for param in param_names_twpt_all_sims]

# Print the marginalized means and uncertainties
print("Marginalized Means and Uncertainties for all_sims:")
for param, mean, sigma in zip(param_names_all_sims, mean_all_sims, sigma_all_sims):
    print(f"{param}: {float(mean):.4f} ± {float(sigma):.4f}")

print("\nMarginalized Means and Uncertainties for map3_all_sims:")
for param, mean, sigma in zip(param_names_map3_all_sims, mean_map3_all_sims, sigma_map3_all_sims):
    print(f"{param}: {float(mean):.4f} ± {float(sigma):.4f}")

print("\nMarginalized Means and Uncertainties for twpt_all_sims:")
for param, mean, sigma in zip(param_names_twpt_all_sims, mean_twpt_all_sims, sigma_twpt_all_sims):
    print(f"{param}: {float(mean):.4f} ± {float(sigma):.4f}")

# %%
# Define the parameters you're interested in
params = ['om', 's8', 'h0', 'cosmological_parameters--n_s', 'cosmological_parameters--omega_b', 'cosmological_parameters--mnu', 'w0']

for param in params:
    # Get quantiles for the parameter (68% confidence interval)
    v1 = twopoint_wCDM.confidence(param, 0.16, upper=False)
    v2 = twopoint_wCDM.confidence(param, 0.16, upper=True)
    
    # Compute the peak (mean)
    peak = twopoint_wCDM.getMeans()
    
    print(f"Parameter: {param}")
    print(f"Peak: {peak}")
    print(f"1-sigma Lower: {v1}")
    print(f"1-sigma Upper: {v2}")

# %%
g = plots.get_single_plotter(ratio=1, width_inch=5)
g.plot_2d([twpt_all_sims, auto_all_sims, auto_334_344_all_sims, all_sims], 'om', 's8', filled=True, 
    colors=['gray','red', 'green', 'blue'], alphas=[0.8,0.8, 0.8,0.8], markers={'om': 0.26, 's8':0.782})
g.add_legend(['2PCF', 'joint (auto)', 'joint (auto+334+344)', 'joint (all)'], legend_loc='upper right')
#plt.savefig("../plots/all_500_sims_dv_results.png")
plt.show()

# %%
g = plots.get_single_plotter(ratio=1, width_inch=5)
g.settings.lab_fontsize = 20
g.settings.axes_fontsize = 15
g.settings.figure_legend_frame = False
g.plot_2d([twpt_all_sims, auto_all_sims, auto_334_344_all_sims, all_sims], 'om', 's8', filled=True, 
    colors=['gray','red', 'green', 'blue'], alphas=[0.8,0.8, 0.8,0.8])
g.add_legend(['2PCF', \
    r'+$\langle M_{\rm ap}^3\rangle$ (auto)', 
    r'+$\langle M_{\rm ap}^3\rangle$ (auto+334+344)', 
    r'+$\langle M_{\rm ap}^3\rangle$ (all)'], legend_loc='upper right', fontsize=10)
g.add_x_marker(0.26)
g.add_y_marker(0.782)
g.get_axes().set_xlim(0.1, 0.6)
g.get_axes().set_ylim(0.7, 0.87)
g.export('../plots/contour2d_cosmogrid_dv_and_cov_19Sep24.pdf')

# %%
g = plots.get_single_plotter(ratio=1, width_inch=5)
g.settings.lab_fontsize = 20
g.settings.axes_fontsize = 15
g.settings.figure_legend_frame = False
g.plot_2d([twpt_all_sims_update, auto_all_sims, auto_334_344_all_sims, all_sims], 'om', 's8', filled=True, 
    colors=['gray','red', 'green', 'blue'], alphas=[0.8,0.8, 0.8,0.8])
g.add_legend(['2PCF', \
    r'+$\langle M_{\rm ap}^3\rangle$ (auto)', 
    r'+$\langle M_{\rm ap}^3\rangle$ (auto+334+344)', 
    r'+$\langle M_{\rm ap}^3\rangle$ (all)'], legend_loc='upper right', fontsize=10)
g.add_x_marker(0.26)
g.add_y_marker(0.782)
g.get_axes().set_xlim(0.1, 0.6)
g.get_axes().set_ylim(0.7, 0.87)
#g.export('../plots/contour2d_cosmogrid_dv_and_cov_5Sep24.pdf')

# %%
g = plots.get_single_plotter(ratio=1, width_inch=5)
g.settings.lab_fontsize = 20
g.settings.axes_fontsize = 15
g.settings.figure_legend_frame = False
g.plot_2d([twpt_all_sims, twpt_all_sims_update], 'om', 's8', filled=True, 
    colors=['green','red'], alphas=[0.8,0.8])
g.add_legend(['2PCF (analytic cov)','2PCF (updated)'], legend_loc='upper right', fontsize=10)
g.add_x_marker(0.26)
g.add_y_marker(0.782)
g.get_axes().set_xlim(0.1, 0.6)
g.get_axes().set_ylim(0.7, 0.87)
#g.export('../plots/contour2d_cosmogrid_dv_and_cov_5Sep24.pdf')

# %%
g = plots.get_single_plotter(ratio=1, width_inch=5)
g.settings.lab_fontsize = 20
g.settings.axes_fontsize = 15
g.settings.figure_legend_frame = False
g.plot_2d([desy3_dm, desy3_baryon], 'om', 's8', filled=True, 
    colors=['green','red'], alphas=[0.8,0.8])
g.add_legend(['dm','baryon'], legend_loc='upper right', fontsize=10)
g.add_x_marker(0.26)
g.add_y_marker(0.782)
g.get_axes().set_xlim(0.1, 0.6)
g.get_axes().set_ylim(0.7, 0.87)
#g.export('../plots/contour2d_cosmogrid_dv_and_cov_5Sep24.pdf')

# %%
# Define the parameters you're interested in
params = ['om', 's8', 'h0', 'cosmological_parameters--n_s', 'cosmological_parameters--omega_b', 'cosmological_parameters--mnu', 'w0']

for param in params:
    # Get quantiles for the parameter (68% confidence interval)
    v1 = desy3_baryon.confidence(param, 0.16, upper=False)
    v2 = desy3_baryon.confidence(param, 0.16, upper=True)
    
    # Compute the peak (mean)
    peak = desy3_baryon.getMeans()
    
    print(f"Parameter: {param}")
    print(f"Peak: {peak}")
    print(f"1-sigma Lower: {v1}")
    print(f"1-sigma Upper: {v2}")

# %%
g = plots.get_single_plotter(ratio=1, width_inch=5)
g.settings.lab_fontsize = 20
g.settings.axes_fontsize = 15
g.settings.figure_legend_frame = False
g.plot_2d([twopoint_wCDM, all_sims_wCDM], 's8', 'w0', filled=True, 
    colors=['gray', 'red', 'blue', 'green'], alphas=[0.8, 0.8, 0.8])
g.add_legend([r'2PCF', r'+$\langle M_{\rm ap}^3\rangle$'], legend_loc='upper right')
g.add_x_marker(0.782)
g.add_y_marker(-1.0)
#plt.suptitle(r'$w$CDM', y=1.02, x = 0.59, fontsize=14)
plt.savefig('../plots/wCDM_contour2d_cosmogrid_dv_and_cov_25Sep24.pdf')

# %%
import numpy as np

# Load the MCMC samples from your file
# Assuming your file is a space-separated text file with columns corresponding to parameters and log-posterior
data1 = np.loadtxt('../output/some-sims-dv-cosmogrid/des-y3-2pt-map3-all-sim1.txt')
data2 = np.loadtxt('../output/some-sims-dv-cosmogrid/des-y3-2pt-map3-all-sim2.txt')
data3 = np.loadtxt('../output/some-sims-dv-cosmogrid/des-y3-2pt-map3-all-sim3.txt')

data_all = np.loadtxt('../output/test-cosmogridc-joint-2pt-moped-run-weighted/des-y3-2pt-map3-all.txt')
map3_data_all = np.loadtxt('../output/test-cosmogridc-joint-2pt-moped-run-weighted/des-y3-map3-all.txt')
twpt_data_all = np.loadtxt('../output/test-cosmogridc-joint-2pt-moped-run-weighted/des-y3-2pt-500simcov.txt')

log_posterior = twpt_data_all[:, -2]
parameters = twpt_data_all[:, :-2]

# Find the index of the sample with the highest log-posterior
best_fit_index = np.argmax(log_posterior)
best_fit_params = parameters[best_fit_index]

print("Best-fit parameters:")
for i, param_value in enumerate(best_fit_params):
    print(f"Parameter {i}: {param_value:.5f}")

# %%
thpt1 = threepoint.ThreePointDataClass.from_fits('../data/dv/meas_map3-sim1-cosmogrid.fits')
thpt2 = threepoint.ThreePointDataClass.from_fits('../data/dv/meas_map3-sim2-cosmogrid.fits')
thpt3 = threepoint.ThreePointDataClass.from_fits('../data/dv/meas_map3-sim3-cosmogrid.fits')
thpt_all = threepoint.ThreePointDataClass.from_fits('../data/dv/meas_map3-ave-cosmogrid_weighted.fits')

thpt_bf_sim1 = threepoint.ThreePointDataClass.from_fits('../data/dv/sim_map3-NLA-some-sims-sim1-BESTFIT.fits')
thpt_bf_sim2 = threepoint.ThreePointDataClass.from_fits('../data/dv/sim_map3-NLA-some-sims-sim2-BESTFIT.fits')
thpt_bf_sim3 = threepoint.ThreePointDataClass.from_fits('../data/dv/sim_map3-NLA-some-sims-sim3-BESTFIT.fits')
thpt_bf_all = threepoint.ThreePointDataClass.from_fits('../data/dv/sim_map3-NLA-some-sims-sims_all-BESTFIT.fits')

thpt_theo = threepoint.ThreePointDataClass.from_fits('../data/dv/sim_map3-NLA-theory-cosmogrid-params-Aug15.fits')
thpt_theo_huge_IA = threepoint.ThreePointDataClass.from_fits('../data/dv/sim_map3-NLA-theory-cosmogrid-params-huge_IA.fits')
thpt_bf_map3_all = threepoint.ThreePointDataClass.from_fits('../data/dv/sim_map3-NLA-some-sims-map3-sims_all-BESTFIT.fits')

# %%
line_args = dict(color='g', ls='-')
fig, axes = thpt_all.plot2d(4, 5, figsize=(25, 20), **line_args)
#line_args2 = dict(color='C0', lw=3, ls=':')
#fig, axes = thpt_theo.plot2d(4, 5, figaxes=(fig, axes), ebar=False, **line_args2)
line_args2 = dict(color='r', lw=3, ls='-')
fig, axes = thpt_theo.plot2d(4, 5, figaxes=(fig, axes), ebar=False, **line_args2)
line_args3 = dict(color='b', alpha=0.7, lw=2, ls='-')
fig, axes = thpt_theo_huge_IA.plot2d(4, 5, figaxes=(fig, axes), ebar=False, **line_args3)
for ax in axes.flatten():
    ax.grid(True)
    ax.set_ylim(-10,60)
#plt.savefig("../plots/Map3_average_of_cosmogrid_sims_with_theory_and_IA_5Sep24.png")

# %%
from astropy.io import fits
twopt1_file = fits.open('../data/dv/sim_2pt-NLA-some-sims-sim1-BESTFIT.fits')
twopt2_file = fits.open('../data/dv/sim_2pt-NLA-some-sims-sim2-BESTFIT.fits')
twopt3_file = fits.open('../data/dv/sim_2pt-NLA-some-sims-sim3-BESTFIT.fits')
twopt_all_file = fits.open('../data/dv/sim_2pt-NLA-some-sims-sims_all-BESTFIT.fits')
twopt_all_2ptbf = fits.open('../data/dv/sim_2pt-NLA-some-sims-2pt-sims_all-BESTFIT.fits')

# %%
twopt1_data = fits.open('../data/dv/meas_2pt-sim1-cosmogrid.fits')
twopt2_data = fits.open('../data/dv/meas_2pt-sim2-cosmogrid.fits')
twopt3_data = fits.open('../data/dv/meas_2pt-sim3-cosmogrid.fits')
twopt_all_data = fits.open('../data/dv/meas_2pt-ave-cosmogrid_weighted.fits')

# %%
def extract_2pt(fitsfile):
    
    xip = fitsfile[2].data
    xim = fitsfile[3].data
    
    out = np.zeros(400)
    for i in range(200):
        out[i] = fitsfile[2].data[i][3]
        out[i+200] = fitsfile[3].data[i][3]
        
    return(out)

# %%
def transform_data(datav):
    transf_moped = np.loadtxt('../data/moped/moped-moped-compress-2pt.txt')
    transformed_data = np.dot(transf_moped.T, datav)
    return(transformed_data)

def transform_cov(covm):
    transf_moped = np.loadtxt('../data/moped/moped-moped-compress-2pt.txt')
    newtransf = np.zeros(shape=(307,96))
    print(np.shape(newtransf[:227,:][:,:16]))
    newtransf[:227,:][:,:16] = transf_moped
    newtransf[227:,:][:,16:] = np.eye(80)
    transformed_cov = np.dot(newtransf.T, np.dot(covm, newtransf))
    return(transformed_cov)

# %%
scale_cut_indices_xip = np.array([20,21,22,23,40,41,42,43,60,61,62,80,81,82,83,100,101,102,103,120,121,122,123,140,141,142,143,160,161,162,163,180,181,182])

# %%
scale_cut_indices_xim = np.concatenate((np.arange(200,210), np.arange(220,234),np.arange(240,254), np.arange(260,273), np.arange(280,294), np.arange(300,315), np.arange(320,335), np.arange(340,355), np.arange(360,375), np.arange(380,394)))

# %%
scale_cuts_all = np.concatenate((scale_cut_indices_xip, scale_cut_indices_xim))

# %%
def scale_cut_2pt(vector):
    scale_cut_indices_xip = np.array([20,21,22,23,40,41,42,43,60,61,62,80,81,82,83,100,101,102,103,120,121,122,123,140,141,142,143,160,161,162,163,180,181,182])
    scale_cut_indices_xim = np.concatenate((np.arange(200,210), np.arange(220,234),np.arange(240,254), np.arange(260,273), np.arange(280,294), np.arange(300,315), np.arange(320,335), np.arange(340,355), np.arange(360,375), np.arange(380,394)))
    scale_cuts_all = np.concatenate((scale_cut_indices_xip, scale_cut_indices_xim))
    return (np.delete(vector, scale_cuts_all))

# %%
def scale_cut_2pt_cov(matrix):
    scale_cut_indices_xip = np.array([20,21,22,23,40,41,42,43,60,61,62,80,81,82,83,100,101,102,103,120,121,122,123,140,141,142,143,160,161,162,163,180,181,182])
    scale_cut_indices_xim = np.concatenate((np.arange(200,210), np.arange(220,234),np.arange(240,254), np.arange(260,273), np.arange(280,294), np.arange(300,315), np.arange(320,335), np.arange(340,355), np.arange(360,375), np.arange(380,394)))
    scale_cuts_all = np.concatenate((scale_cut_indices_xip, scale_cut_indices_xim))
    matrix = np.delete(matrix, scale_cuts_all, axis=0)
    matrix = np.delete(matrix, scale_cuts_all, axis=1)
    return (matrix)

# %%
from astropy.io import fits
to_cov = fits.open("../data/covariance/cov_xip_xim_map3.fits")
cov_all_nocut = to_cov[1].data
cov_all = transform_cov(scale_cut_2pt_cov(cov_all_nocut))

# %%
twpt1 = transform_data(scale_cut_2pt(extract_2pt(twopt1_data)))
twpt2 = transform_data(scale_cut_2pt(extract_2pt(twopt2_data)))
twpt3 = transform_data(scale_cut_2pt(extract_2pt(twopt3_data)))
twpt_all = transform_data(scale_cut_2pt(extract_2pt(twopt_all_data)))

twpt_bf_sim1 = transform_data(scale_cut_2pt(extract_2pt(twopt1_file)))
twpt_bf_sim2 = transform_data(scale_cut_2pt(extract_2pt(twopt2_file)))
twpt_bf_sim3 = transform_data(scale_cut_2pt(extract_2pt(twopt3_file)))
twpt_bf_all = transform_data(scale_cut_2pt(extract_2pt(twopt_all_file)))

twpt_bf_only = transform_data(scale_cut_2pt(extract_2pt(twopt_all_2ptbf)))

# %%
dados1 = np.concatenate((twpt1,thpt1.get_signal()))
dados2 = np.concatenate((twpt2,thpt2.get_signal()))
dados3 = np.concatenate((twpt3,thpt3.get_signal()))
dados_all = np.concatenate((twpt_all,thpt_all.get_signal()))

teoria1 = np.concatenate((twpt_bf_sim1,thpt_bf_sim1.get_signal()))
teoria2 = np.concatenate((twpt_bf_sim2,thpt_bf_sim2.get_signal()))
teoria3 = np.concatenate((twpt_bf_sim3,thpt_bf_sim3.get_signal()))
teoria_all = np.concatenate((twpt_bf_all,thpt_bf_all.get_signal()))

# %%
minus_file = fits.open('../data/dv/sim_map3-NLA-cosmoCosmoG-mnutest0.fits')
minus_file.info()
dataminus = minus_file[1].data
print(dataminus)
for i in range(len(dataminus)):
    dataminus[i][6] = -1*dataminus[i][6]

plus_file = minus_file
plus_file[1].data = dataminus
#output_path = '../data/dv/altered_sign_sim_map3-NLA-cosmoCosmoG-mnutest0-emulated.fits'
#plus_file.writeto(output_path, overwrite=False)

# %%
plus_file = fits.open('../data/dv/sim_map3-NLA-cosmoCosmoG-mnutest0-emulated.fits')
plus_file.info()
dataplus = plus_file[1].data
print(dataplus)

# %%
theory_mnu009 = threepoint.ThreePointDataClass.from_fits('../data/dv/altered_sign_sim_map3-NLA-cosmoCosmoG-mnutest0.fits')
thmnu_009 = -1*theory_mnu009.get_signal()
thmnu_006 = thpt_theo.get_signal()
datamap3 = thpt_all.get_signal()

# %%
diff_mnu006 = datamap3 - thmnu_006
diff_mnu009 = datamap3 - thmnu_009

numm = (500-diff_mnu006.size-2)/(500-1)
invcovar = np.linalg.inv(cov_all[16:,:][:,16:]) * numm
chi2mnu006 = diff_mnu006.dot(invcovar).dot(diff_mnu006)
dofmnu006  = diff_mnu006.size
print('{:.3f}/{}={:.3f}'.format(chi2mnu006, dofmnu006, chi2mnu006/dofmnu006))
chi2mnu009 = diff_mnu009.dot(invcovar).dot(diff_mnu009)
dofmnu009  = diff_mnu009.size
print('{:.3f}/{}={:.3f}'.format(chi2mnu009, dofmnu009, chi2mnu009/dofmnu009))

# %%
line_args = dict(color='g', ls='-')
fig, axes = thpt_all.plot2d(4, 5, figsize=(25, 20), **line_args)
line_args2 = dict(color='r', lw=3, ls='-')
fig, axes = thpt_theo.plot2d(4, 5, figaxes=(fig, axes), ebar=False, **line_args2)
line_args3 = dict(color='b', alpha=0.7, lw=2, ls='-')
fig, axes = theory_mnu009.plot2d(4, 5, figaxes=(fig, axes), ebar=False, **line_args3)
for ax in axes.flatten():
    ax.grid(True)
    ax.set_ylim(-10,60)
plt.show()

# %%
dife1 = dados1 - teoria1
dife2 = dados2 - teoria2
dife3 = dados3 - teoria3
dife_all = dados_all - teoria_all

f = (500-dife1.size-2)/(500-1)
icov_all = np.linalg.inv(cov_all) * f

chi21 = dife1.dot(icov_all).dot(dife1)
dof1  = dife1.size
print('{:.3f}/{}={:.3f}'.format(chi21, dof1, chi21/dof1))

chi22 = dife2.dot(icov_all).dot(dife2)
dof2  = dife2.size
print('{:.3f}/{}={:.3f}'.format(chi22, dof2, chi22/dof2))

chi23 = dife3.dot(icov_all).dot(dife3)
dof3  = dife3.size
print('{:.3f}/{}={:.3f}'.format(chi23, dof3, chi23/dof3))

chi2_all = dife_all.dot(icov_all).dot(dife_all)
dof_all  = dife_all.size
print('{:.3f}/{}={:.3f}'.format(chi2_all, dof_all, chi2_all/dof_all))

# %%
dadosm = thpt_all.get_signal()
teoriam = thpt_bf_map3_all.get_signal()

difem = dadosm - teoriam
cov_allm = to_cov[1].data[400:,:][:,400:]

f = (500-difem.size-2)/(500-1)
icov_allm = np.linalg.inv(cov_allm) * f

chi2m = difem.dot(icov_allm).dot(difem)
dofm  = difem.size
print('{:.3f}/{}={:.3f}'.format(chi2m, dofm, chi2m/dofm))

# %%
dadosx = twpt_all
teoriax = twpt_bf_only

difex = dadosx - teoriax
cov_allx = cov_all[:16,:][:,:16]

f = (500-difex.size-2)/(500-1)
icov_allx = np.linalg.inv(cov_allx) * f

chi2x = difex.dot(icov_allx).dot(difex)
dofx  = difex.size
print('{:.3f}/{}={:.3f}'.format(chi2x, dofx, chi2x/dofx))
