# %%
from astropy.io import fits

# %%
file = fits.open("/Users/gchgomes/3pcf_integrator/data/dv/sim_map3-NLA-cosmoDESY3.fits")

# %%
file.info()
# Out:
# Filename: /Users/gchgomes/3pcf_integrator/data/dv/sim_map3-NLA-cosmoDESY3.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  map3          1 BinTableHDU     29   80R x 7C   [K, K, K, D, D, D, D]
#   2  COVMAT        1 ImageHDU        12   (80, 80)   float64

# %%
file[1].header
# Out:
# XTENSION= 'BINTABLE'           / binary table extension
# BITPIX  =                    8 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   56 / length of dimension 1
# NAXIS2  =                   80 / length of dimension 2
# PCOUNT  =                    0 / number of group parameters
# GCOUNT  =                    1 / number of groups
# TFIELDS =                    7 / number of table fields
# BIN_TYPE= 'SSS     '
# EXTNAME = 'map3    '
# KERNEL_1= 'nz_source'
# KERNEL_2= 'nz_source'
# KERNEL_3= 'nz_source'
# SORTZ   =                    T
# 3PT_DATA=                    T
# TTYPE1  = 'BIN1    '
# TFORM1  = 'K       '
# TTYPE2  = 'BIN2    '
# TFORM2  = 'K       '
# TTYPE3  = 'BIN3    '
# TFORM3  = 'K       '
# TTYPE4  = 'THETA1  '
# TFORM4  = 'D       '
# TTYPE5  = 'THETA2  '
# TFORM5  = 'D       '
# TTYPE6  = 'THETA3  '
# TFORM6  = 'D       '
# TTYPE7  = 'VALUE   '
# TFORM7  = 'D       '

# %%
file[1].data
# Out:
# FITS_rec([(1, 1, 1,  7.,  7.,  7.,  4.53980155e-08),
#           (1, 1, 1, 14., 14., 14.,  6.67905860e-10),
#           (1, 1, 1, 25., 25., 25., -2.50322432e-11),
#           (1, 1, 1, 40., 40., 40., -1.54378180e-11),
#           (1, 1, 2,  7.,  7.,  7.,  6.80215433e-09),
#           (1, 1, 2, 14., 14., 14.,  4.57963649e-11),
#           (1, 1, 2, 25., 25., 25., -4.46999038e-11),
#           (1, 1, 2, 40., 40., 40., -8.20986183e-12),
#           (1, 1, 3,  7.,  7.,  7., -4.38226125e-09),
#           (1, 1, 3, 14., 14., 14., -2.66143579e-10),
#           (1, 1, 3, 25., 25., 25., -1.11557639e-10),
#           (1, 1, 3, 40., 40., 40., -1.83126054e-11),
#           (1, 1, 4,  7.,  7.,  7.,  7.84562752e-09),
#           (1, 1, 4, 14., 14., 14., -1.31271363e-11),
#           (1, 1, 4, 25., 25., 25., -5.55402896e-11),
#           (1, 1, 4, 40., 40., 40., -2.53710338e-11),
#           (1, 2, 2,  7.,  7.,  7.,  6.58382474e-09),
#           (1, 2, 2, 14., 14., 14., -4.24411673e-10),
# ...

# %%
file[2].data
# Out:
# array([[ 3.23214678e-16,  6.28688783e-18,  1.34647838e-19, ...,
#         -5.06214798e-18, -9.46868551e-20, -1.17533530e-19],
#        [ 6.28688783e-18,  4.04340966e-19,  2.49915530e-20, ...,
#         -4.21779124e-20, -2.13548327e-21, -5.17987476e-21],
#        [ 1.34647838e-19,  2.49915530e-20,  8.68927283e-21, ...,
#         -6.27419077e-21, -2.53430838e-21, -6.89025152e-22],
#        ...,
#        [-5.06214798e-18, -4.21779124e-20, -6.27419077e-21, ...,
#          3.03987684e-18,  2.66580619e-19,  1.84851745e-20],
#        [-9.46868551e-20, -2.13548327e-21, -2.53430838e-21, ...,
#          2.66580619e-19,  9.81305320e-20,  1.13158728e-20],
#        [-1.17533530e-19, -5.17987476e-21, -6.89025152e-22, ...,
#          1.84851745e-20,  1.13158728e-20,  3.98618138e-21]], dtype='>f8')

# %%
file[2].data[10]
# Out:
# array([-8.23008823e-20,  5.12654338e-21,  2.04347946e-21,  2.11691224e-22,
#         3.34962790e-20,  2.32942417e-21,  1.17005866e-21,  1.65840781e-22,
#         3.46998780e-20,  9.06219439e-21,  5.04500251e-21,  6.45222230e-22,
#        -1.91510620e-20,  4.99690926e-21,  1.87652268e-21,  2.56104712e-22,
#         8.02011966e-20,  4.22811505e-21,  7.95397899e-22,  1.07815553e-22,
#        -2.08459172e-20,  1.80036118e-21,  6.45874785e-22,  9.59464994e-23,
#         1.59094735e-20,  2.15645341e-21,  1.08988053e-21,  2.17125573e-22,
#        -7.83033685e-20,  2.04246437e-21,  8.79346215e-22,  2.43144500e-23,
#        -6.61569641e-20,  2.62885397e-21,  1.06989931e-21,  1.40127720e-22,
#         9.95285446e-20,  6.63017289e-21,  1.81335257e-21,  3.72491082e-22,
#         2.05129481e-19, -2.03715695e-21, -7.46073702e-22,  1.26389708e-22,
#         1.19334653e-20,  1.16412551e-21, -3.02955523e-22, -1.63821959e-22,
# ...
