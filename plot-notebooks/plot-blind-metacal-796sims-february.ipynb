# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
import sys
sys.path.append('../python')
import utils
import threepoint

# %%
blind = True
file1 = '../output/blind-metacal-796sims-february/des-y3-2pt-blind-metacal-simcov.txt'
file2 = '../output/blind-metacal-796sims-february/des-y3-2pt-map3-all-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly, desy3_joint = chains[0], chains[1]
# Out:
# ../output/blind-metacal-796sims-february/des-y3-2pt-blind-metacal-simcov.txt
# 8
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-796sims-february/des-y3-2pt-map3-all-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
blind = True
file1 = '../output/blind-metacal-796sims-february/des-y3-2pt-blind-metacal-simcov.txt'
file2 = '../output/blind-metacal-796sims-february/des-y3-map3-all-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly, desy3_map3 = chains[0], chains[1]
# Out:
# ../output/blind-metacal-796sims-february/des-y3-2pt-blind-metacal-simcov.txt
# 8
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-796sims-february/des-y3-map3-all-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
blind = True
file1 = '../output/blind-metacal-796sims-february-Percival/des-y3-2pt-blind-metacal-simcov.txt'
file2 = '../output/blind-metacal-796sims-february-Percival/des-y3-2pt-map3-all-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly, desy3_joint = chains[0], chains[1]
# Out:
# ../output/blind-metacal-796sims-february-Percival/des-y3-2pt-blind-metacal-simcov.txt
# 8
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-796sims-february-Percival/des-y3-2pt-map3-all-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
blind = True
file1 = '../output/blind-metacal-796sims-february-Percival/des-y3-2pt-blind-metacal-simcov.txt'
file2 = '../output/blind-metacal-796sims-february-Percival/des-y3-map3-all-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
desy3_2ptonly, desy3_map3 = chains[0], chains[1]
# Out:
# ../output/blind-metacal-796sims-february-Percival/des-y3-2pt-blind-metacal-simcov.txt
# 8
# Blinding  ['om', 'h0', 'ob', 'ns', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-796sims-february-Percival/des-y3-map3-all-blind-metacal.txt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 5
#       3 file2 = '../output/blind-metacal-796sims-february-Percival/des-y3-map3-all-blind-metacal.txt'
#       4 files = [file1, file2]
# ----> 5 chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
#       6 desy3_2ptonly, desy3_map3 = chains[0], chains[1]
#
# File ~/3pcf_integrator/plot-notebooks/../python/utils.py:171, in read_cosmosis_mcmc_des_blind_chains(fnames, mapping, take, to_mcsamples, fname_mean, wplot)
#     169 else:
#     170     mapping |= get_preset_mapping('des')
# ...

# %%
blind = True
file1 = '../output/blind-metacal-8arcmincut-december/des-y3-2pt-500simcov-wCDM-blind-metacal.txt'
file2 = '../output/blind-metacal-8arcmincut-december/des-y3-2pt-map3-all-wCDM-blind-metacal.txt'
files = [file1, file2]
chains = utils.read_cosmosis_mcmc_des_blind_chains(files, to_mcsamples=True)
wcdm_2ptonly, wcdm_joint = chains[0], chains[1]
# Out:
# WARNING:root:outlier fraction 0.015748031496062992
# ../output/blind-metacal-8arcmincut-december/des-y3-2pt-500simcov-wCDM-blind-metacal.txt
# 9
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in
# ../output/blind-metacal-8arcmincut-december/des-y3-2pt-map3-all-wCDM-blind-metacal.txt
# Blinding  ['om', 'h0', 'ob', 'ns', 'w0', 's8', 'mnu', 'sig8', 'COSMOLOGICAL_PARAMETERS--SIGMA_12']
# Removed no burn in

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.settings.lab_fontsize = 17
g.settings.axes_fontsize = 13
g.settings.legend_fontsize = 16
g.settings.figure_legend_frame = True
g.triangle_plot([desy3_2ptonly, desy3_joint, desy3_map3], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=[r'$\xi_{\pm}$',r'$\xi_{\pm}$+$\langle M_{\rm ap}^3\rangle$', r'$\langle M_{\rm ap}^3\rangle$'], legend_loc='upper right', 
    contour_colors=['gray', 'red', 'green'], markers={'om':0.26, 's8':0.782, 'sig8':0.84, 'a1':0})
plt.show()

# %%
#percival fom
fom_2pt = utils.FoM_from_samples_names(desy3_2ptonly, ['om', 's8'])
joint_fom = utils.FoM_from_samples_names(desy3_joint, ['om', 's8'])

print(fom_2pt, joint_fom)
print(joint_fom/fom_2pt)
# Out:
# 804.6074322247002 1969.6795013737574
# 2.4480006304785054

# %%
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.settings.lab_fontsize = 17
g.settings.axes_fontsize = 13
g.settings.legend_fontsize = 16
g.settings.figure_legend_frame = True
g.triangle_plot([desy3_2ptonly, desy3_joint], ['om', 's8', 'sig8', 'a1'], filled=False, \
    legend_labels=[r'$\xi_{\pm}$',r'$\xi_{\pm}$+$\langle M_{\rm ap}^3\rangle$'], legend_loc='upper right', 
    contour_colors=['gray', 'red'], markers={'om':0.26, 's8':0.782, 'sig8':0.84, 'a1':0})
#plt.show()
plt.savefig("Y3_blind_chains_percival.pdf")

# %%
#percival fom
fom_2pt = utils.FoM_from_samples_names(desy3_2ptonly, ['om', 's8'])
joint_fom = utils.FoM_from_samples_names(desy3_joint, ['om', 's8'])

print(fom_2pt, joint_fom)
print(joint_fom/fom_2pt)
# Out:
# 804.7483250739393 1810.5045173039757
# 2.2497773041498768

# %%
plt.rcParams['axes.linewidth'] = 2
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.settings.lab_fontsize = 17
g.settings.axes_fontsize = 14
g.settings.legend_fontsize = 18
g.settings.figure_legend_frame = True

# Apply the custom labels to the plotter
#g.set_labels(custom_labels)
g.triangle_plot([desy3_2ptonly, desy3_joint], ['om', 's8', 'sig8','h0', 'ob', 'ns', 'a1', 'alpha1'], filled=False, \
    legend_labels=[r'$\xi_{\pm}$',r'$\xi_{\pm}$+$\langle M_{\rm ap}^3\rangle$'], legend_loc='upper right', 
    contour_colors=['blue', 'red'], markers={'om':0.26, 's8':0.782, 'sig8':0.84, 'a1':0, 'ns':0.9649, 'h0':0.673, 'ob':0.0493})

plt.savefig("DESY3_blind_manyparams_lcdm_6March.pdf")
#plt.show()

# %%
plt.rcParams['axes.linewidth'] = 2
g = plots.get_single_plotter(ratio=1, width_inch=6)
g.settings.lab_fontsize = 17
g.settings.axes_fontsize = 14
g.settings.legend_fontsize = 18
g.settings.figure_legend_frame = True

# Apply the custom labels to the plotter
#g.set_labels(custom_labels)
g.triangle_plot([wcdm_2ptonly, wcdm_joint], ['om', 's8', 'sig8','h0', 'ob', 'ns', 'a1', 'alpha1'], filled=False, \
    legend_labels=[r'$\xi_{\pm}$',r'$\xi_{\pm}$+$\langle M_{\rm ap}^3\rangle$'], legend_loc='upper right', 
    contour_colors=['blue', 'red'], markers={'om':0.26, 's8':0.782, 'sig8':0.84, 'a1':0, 'ns':0.9649, 'h0':0.673, 'ob':0.0493})

plt.savefig("DESY3_blind_manyparams_wcdm.pdf")
#plt.show()
