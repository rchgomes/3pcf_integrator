# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
import sys
sys.path.append('../python')
import utils
import threepoint
from astropy.io import fits

# %%
#view old 2pt file
twopt = fits.open('../data/dv/blind-metacal-2pt-DESY3-796SimCov-weighted.fits')
#twopt = fits.open('../data/dv/blind-metacal-2pt-DESY3.fits')
twopt.info()
twopt[1].header
# Out:
# Filename: ../data/dv/blind-metacal-2pt-DESY3-796SimCov-weighted.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  COVMAT        1 ImageHDU        17   (400, 400)   float64
#   2  xip           1 BinTableHDU     35   200R x 7C   [K, K, K, D, D, D, D]
#   3  xim           1 BinTableHDU     35   200R x 7C   [K, K, K, D, D, D, D]
#   4  nz_source     1 BinTableHDU     24   301R x 7C   [D, D, D, D, D, D, D]
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  400
# NAXIS2  =                  400
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# COVDATA =                    T
# EXTNAME = 'COVMAT  '
# STRT_0  =                    0
# NAME_0  = 'xip     '
# STRT_1  =                  200
# NAME_1  = 'xim     '
# ...

# %%
newxip = np.load('../data/dv/2pcf_unblinded_y3_xip.npy')
newxim = np.load('../data/dv/2pcf_unblinded_y3_xim.npy')

# %%
for i in range(200):
    twopt[2].data[i][3] = newxip[i]
    twopt[3].data[i][3] = newxim[i]

# %%
twopt.writeto('../data/dv/real_2pt_desy3_unblind_2025Mar7.fits')

# %%
x = fits.open('../data/dv/real_map3_desy3_blind_FEBRUARY2025_796simcov.fits')
x.info()
# Out:
# Filename: ../data/dv/real_map3_desy3_blind_FEBRUARY2025_796simcov.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  map3          1 BinTableHDU     29   80R x 7C   [K, K, K, D, D, D, D]
#   2  COVMAT        1 ImageHDU        12   (80, 80)   float64

# %%
twopt_simcov = fits.open('../data/dv/blind-metacal-2pt-DESY3-796SimCov-weighted.fits')
twopt_simcov.info()

# %%
print(twopt_simcov[1].data/twopt[1].data)

# %%
newcov = np.load('../data/dv/average_map3_796sims/xip_xim_map3_covariance_8ARCMINCUT_24Feb25.npy')
old_cov.info()
old_cov[1].data = newcov
#old_cov.writeto('../data/covariance/xip_xim_map3_covariance_8ARCMINCUT_25Feb25.fits', overwrite=True)

# %%
#2pt simcov cov
open2pt = fits.open('../data/dv/sim_2pt-NLA-cosmoCosmogrid-04Nov24_500simcov.fits')
open2pt.info()
