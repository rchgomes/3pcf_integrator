# %%
import numpy as np

# Original data provided in two columns
data = np.array([
    [0.023978848631639803, 60604.304134027974],
    [0.023978848631639803, 129816.69153216945],
    [0.04274657147989057, 15126.595670578483],
    [0.04274657147989057, 41288.72043939816],
    [0.07620338246242273, 24491.140129749827],
    [0.07620338246242273, 35844.500850119846],
    [0.13584611110732178, 2163.3107737371683],
    [0.13584611110732178, 5904.853656801445],
    [0.24216990514932696, 3885.9705040643994],
    [0.24216990514932696, 5887.76717025843],
    [0.4317110183132296, 710.2297883727856],
    [0.4317110183132296, 1324.5720149613237],
    [0.7582777734439359, 196.6897210761756],
    [0.7582777734439359, 406.97819204256126],
    [1.3517652803964857, 41.288720439398205],
    [1.3517652803964857, 138.722597949549]
])

# Separate the columns
col1 = data[::2, 0]  # Every second entry from the first column
mean_col2 = (data[::2, 1] + data[1::2, 1]) / 2  # Mean of pairs in the second column
range_col2 = data[1::2, 1] - data[::2, 1]       # Range (difference) of pairs in the second column

# Combine into a single array
result = np.column_stack((col1, mean_col2, range_col2))

# Save to a numpy file
np.save('/Users/gchgomes/Topics_in_Cosmology/pk_des_data.npy', result)
