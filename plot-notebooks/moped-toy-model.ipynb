# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reproducing the findings of Hartlap+
# Let's see the simulation-based inverse covariance underestimate the error size.
# To do so, we first define the number of data dimension $p$ and the number of simulations $N$. Then we
# 1. create a random covariance = this is the true covariance, call it `c`
# 2. simulate $N$ samples, call `x`
# 3. estimate the covariance from the sims, call it `c_est`
# 4. Generate the test random samples that follow `c`
# 5. compute chi-square using `c` and `c_est`, and see the difference of chi-square distribution.

# %%
rng = np.random.default_rng(0)

# %%
def get_random_covariance(N):
    a = rng.random(N*N).reshape(N,N)
    c = np.dot(a, a.T)
    return c

# %%
p = 100
N = 300

# true
c = get_random_covariance(p)
ic= np.linalg.inv(c)

# generate samples
x = rng.multivariate_normal(np.zeros(p), c, N)
c_est = np.cov(x.T)
ic_est= np.linalg.inv(c_est)

# simulate validation samples
n_test = 10000
x2= rng.multivariate_normal(np.zeros(p), c, n_test)
# compute chi2
chi2    = np.array([np.dot(_, np.dot(ic, _)) for _ in x2])
chi2_est= np.array([np.dot(_, np.dot(ic_est, _)) for _ in x2])

# %%
plt.figure()
# plt.hist(chi2, bins=bins, alpha=0.6, label='True')
# plt.hist(chi2_est, bins=bins, alpha=0.6, label='Est')
plt.hist(chi2, bins=40, alpha=0.6, label='True')
plt.hist(chi2_est, bins=40, alpha=0.6, label='Est')
# Hartlap prediction
plt.axvline(p, color='C0')
plt.axvline(p/((N-p-2)/(N-1)), color='C1')
plt.legend()
plt.show()

# %% [markdown]
# -----------------
# ## MOPED test

# %%
import emcee
import pymultinest
from getdist import plots, MCSamples

# %%
def model(params, base=None):
    if base is None:
        base = np.linspace(0, 5, p)
    # Example: 4 param model
    # out  = params[0]*np.exp(-params[1]*base) * (1+params[2]*np.exp(-(base-params[3])**2)/3)
    # Example: 3 param model
    out = params[0] * np.exp(-params[1]*base) + params[2]*np.exp(-(base-2.5)**2/2/0.3**2)
    return out

# %%
def compute_moped_matrix(ic, params, dp=0.01):
    # dim os params
    m = len(params)
    # fiducial model
    k = model(params)

    derivatives = np.zeros((m, p))
    for i in range(m):
        # plus
        pp = params.copy()
        pp[i] *= 1+dp
        k_plus = model(pp)
        # plus 2
        pp2 = params.copy()
        pp2[i] *= 1+2*dp
        k_plus2 = model(pp2)
        # minus
        pm = params.copy()
        pm[i] *= 1-dp
        k_minus = model(pm)
        # minus 2
        pm2 = params.copy()
        pm2[i] *= 1-2*dp
        k_minus2 = model(pm2)
        # derivative
        h = params[i] * dp
        d = (-k_plus2 + 8*k_plus - 8*k_minus + k_minus2) / 12/h
        # assign
        derivatives[i] = d

    # compute the moped matrix
    c = np.linalg.inv(ic)
    b = np.zeros((m,p))
    for i in range(m):
        mum_bq = np.einsum('i,qi->q', derivatives[i], b)
        bm = np.dot(ic, derivatives[i])
        bm-= np.einsum('q,qi->i', mum_bq, b)
        bm/= np.abs(np.einsum('i,ij,j->', bm, c, bm))**0.5
        # update matrix
        b[i,:] = bm

    return b

# %%
def lnpost(data, params, ic, b=None, boundary=None):
    theo = model(params)
    if b is not None:
        data = np.dot(b, data)
        theo = np.dot(b, theo)
        c = np.linalg.inv(ic)
        c = np.dot(b, np.dot(c, b.T))
        ic= np.linalg.inv(c)
    diff = data - theo
    chi2 = np.dot(diff, np.dot(ic, diff))
    out = -0.5*chi2

    if boundary is not None:
        for i in range(len(params)):
            if params[i] < boundary[i][0] or params[i] > boundary[i][1]:
                out = -np.inf
    return out

def sample_param(data, ic, params, b=None, nwalkers=10, boundary=None, f_hartlap=1):
    # def temporary_lnpost(params):
    #     return lnpost(data, params, ic, b, boundary) * f_hartlap
    # ndim = len(params)
    # pos = [params + 1e-4*np.random.randn(ndim) for i in range(nwalkers)]
    # sampler = emcee.EnsembleSampler(nwalkers, ndim, temporary_lnpost)
    # sampler.run_mcmc(pos, 2000)
    # samples = sampler.get_chain(discard=100, thin=15, flat=True)
    # return samples

    def lnpost_temp(cube, ndim, nparams):
        params = cube
        return lnpost(data, params, ic, b) * f_hartlap

    def prior_temp(cube, ndim, nparams):
        for i in range(ndim):
            cube[i] = cube[i] * (boundary[i][1] - boundary[i][0]) + boundary[i][0]
    
    n_params = len(params)
    pymultinest.run(lnpost_temp, prior_temp, n_params, outputfiles_basename='../output/moped-toy/temp', resume=False, verbose=False, n_live_points=200)

    samples = np.loadtxt('../output/moped-toy/temp.txt')
    weight = samples[:,0]
    samples = samples[:,2:]

    print(f_hartlap)
    return samples, weight

# %% [markdown]
# #### Noiseless data case

# %%
# problem setup
p = 50
N = 54

# data
params = [3, 0.5, 5]
data = model(params)

# true covariance
c = np.diag(data*0.05)
ic= np.linalg.inv(c)

# sim cov
x = rng.multivariate_normal(np.zeros(p), c, N)
c_est = np.cov(x.T)
ic_est= np.linalg.inv(c_est)

plt.figure(figsize=(12, 3))
# plt.yscale('log')
plt.axhline(0.0, color='k')
plt.grid()
_ = np.linspace(0, 5.5, 100)
plt.plot(_, model(params, _), label='Model')
plt.errorbar(np.linspace(0, 5, p), data, yerr=np.diag(c)**0.5, label='Data', fmt='.')
plt.show()

# %%
names = ['a', 'b', 'c']
boundary = [[0, 5], [0, 2], [0, 10]]

# 1. with true covariance
# %time samples, w = sample_param(data, ic, params, boundary=boundary)
mcs = MCSamples(samples=samples, names=names, label='True', weights=w)
print('True', samples.shape)

# 2. with estimated covariance
# %time samples_est, w = sample_param(data, ic_est, params, boundary=boundary, f_hartlap=(N-p-2)/(N-1))
mcs_est = MCSamples(samples=samples_est, names=names, label=f'Cov from {N} sims', weights=w)
print('Estimated', samples_est.shape)

# 3. moped compression
b = compute_moped_matrix(ic_est, params)
# %time samples_moped, w = sample_param(data, ic_est, params, b=b, boundary=boundary, f_hartlap=(N-len(params)-2)/(N-1))
# %time samples_moped, w = sample_param(data, ic_est, params, b=b, boundary=boundary, f_hartlap=(N-p-2)/(N-1))
mcs_moped = MCSamples(samples=samples_moped, names=names, label=f'MOPED', weights=w)
print('MOPED', samples_moped.shape)
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -9.2296561377005144      +/-  0.19724578914636709
#  Total Likelihood Evaluations:         3347
#  Sampling finished. Exiting MultiNest
# 1
# CPU times: user 525 ms, sys: 87.5 ms, total: 613 ms
# Wall time: 663 ms
# Removed no burn in
# True (2048, 3)
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -8.6071913079771818      +/-  0.18856338904167130
#  Total Likelihood Evaluations:         2981
#  Sampling finished. Exiting MultiNest
# 0.03773584905660377
# CPU times: user 641 ms, sys: 72.5 ms, total: 713 ms
# Wall time: 732 ms
# Removed no burn in
# Estimated (1975, 3)
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -8.1656617752129605      +/-  0.18143998096022790
#  Total Likelihood Evaluations:         3308
#  Sampling finished. Exiting MultiNest
# 0.03773584905660377
# CPU times: user 1.07 s, sys: 83.3 ms, total: 1.15 s
# Wall time: 1.33 s
# Removed no burn in
# MOPED (1892, 3)

# %%
# plt.plot(samples_est[:,2])

# %%
g = plots.get_single_plotter(ratio=1)
g.triangle_plot([mcs, mcs_est, mcs_moped], markers=params, fill=False)
plt.suptitle(f'data dimension = {p}', y=1.02)
# Out:
# Text(0.5, 1.02, 'data dimension = 50')

# %% [markdown]
# ## noisy case
# Here we test the MOPED compression works even on noisy data.
#
# We worry about the scenario where the simuation-based covariance mistakenly underestimate the variance of a specific data vector element due to small number of realization, and the MOPED mistakenly upweight the data vector element that has larger noise than estimated, then it would be possible that the compressed data vector is **not** robust against the noise realization.
#
# *Possible counter argument*: as long as the compressed covariance is accurate, this mistake in choosing the noisy element of the uncompressed data vector could be taken into account by the compressed covariance.

# %%
# %%time
# noise realizations by true covariance
ns = rng.multivariate_normal(np.zeros(p), c, 15)

mcs_n = []
mcs_moped_n = []
for i, n in enumerate(ns):
    data = model(params) + n
    # true
    samples, w = sample_param(data, ic, params, boundary=boundary)
    _ = MCSamples(samples=samples, names=names, label=f'True n{i}', weights=w)
    mcs_n.append(_)
    # moped
    samples, w = sample_param(data, ic, params, b=b, boundary=boundary, f_hartlap=(N-len(params)-2)/(N-1))
    _ = MCSamples(samples=samples, names=names, label=f'MOPED n{i}', weights=w)
    mcs_moped_n.append(_)
# Out:
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -14.616530015835879      +/-  0.16700143686465632
#  Total Likelihood Evaluations:         2478
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.9295731859248857      +/-  0.14377573428816373
#  Total Likelihood Evaluations:         2307
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -11.879529185877143      +/-  0.16346477748306348
#  Total Likelihood Evaluations:         2849
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -6.0696229283612375      +/-  0.14973038119012211
#  Total Likelihood Evaluations:         2426
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -17.062628160972480      +/-  0.16995779776581224
#  Total Likelihood Evaluations:         2696
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.4243037697147605      +/-  0.13970163474383551
#  Total Likelihood Evaluations:         2492
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -10.867811023770740      +/-  0.16079462045908938
#  Total Likelihood Evaluations:         2508
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.8330848681905971      +/-  0.14783470306182964
#  Total Likelihood Evaluations:         2240
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -11.444941889681351      +/-  0.16321926790467414
#  Total Likelihood Evaluations:         2726
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.9435416058427810      +/-  0.14743363550165606
#  Total Likelihood Evaluations:         2264
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -15.888622479295089      +/-  0.16743769645942880
#  Total Likelihood Evaluations:         2648
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.9247779300936960      +/-  0.14811874872852709
#  Total Likelihood Evaluations:         2338
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -16.273552169662967      +/-  0.16484938542689864
#  Total Likelihood Evaluations:         2698
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.7013178833934761      +/-  0.14408358919971648
#  Total Likelihood Evaluations:         2464
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -12.790364931005611      +/-  0.16404063661684543
#  Total Likelihood Evaluations:         2447
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.4423840495770941      +/-  0.13828718483471936
#  Total Likelihood Evaluations:         2227
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -15.241373415070987      +/-  0.15619340167155538
#  Total Likelihood Evaluations:         2477
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.5362870243240421      +/-  0.13441828791494850
#  Total Likelihood Evaluations:         2173
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -16.257354281911987      +/-  0.16266403933800777
#  Total Likelihood Evaluations:         2572
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -4.9491277567133602      +/-  0.12540312132727149
#  Total Likelihood Evaluations:         2059
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -14.160967498684847      +/-  0.16194795155390551
#  Total Likelihood Evaluations:         2484
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.3858826447344059      +/-  0.13788244088581206
#  Total Likelihood Evaluations:         2205
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -15.446896988305600      +/-  0.16418078465708166
#  Total Likelihood Evaluations:         2626
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.9405185319686415      +/-  0.14647813026819850
#  Total Likelihood Evaluations:         2408
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -18.786646276989089      +/-  0.16124120371465384
#  Total Likelihood Evaluations:         2545
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.6187530527512406      +/-  0.14109656482535543
#  Total Likelihood Evaluations:         2183
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -15.269564584290478      +/-  0.16602810858987044
#  Total Likelihood Evaluations:         2501
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -5.8993655197332853      +/-  0.14761712843265984
#  Total Likelihood Evaluations:         2396
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -16.874525348106168      +/-  0.16627053361093802
#  Total Likelihood Evaluations:         2548
#  Sampling finished. Exiting MultiNest
# 1
# Removed no burn in
#  *****************************************************
#  MultiNest v3.10
#  Copyright Farhan Feroz & Mike Hobson
#  Release Jul 2015
#
#  no. of live points =  200
#  dimensionality =    3
#  *****************************************************
#  ln(ev)=  -6.3984393471717063      +/-  0.15670721516361100
#  Total Likelihood Evaluations:         2391
#  Sampling finished. Exiting MultiNest
# 0.8620689655172413
# Removed no burn in
# CPU times: user 38.4 s, sys: 4.67 s, total: 43 s
# Wall time: 55.8 s

# %%
for i in range(len(mcs_moped_n)):
    g = plots.get_single_plotter(ratio=1, width_inch=3)
    g.plot_2d([mcs_n[i], mcs_moped_n[i]], 'a', 'b', filled=False, contour_colors=['k', 'red'])
    ax = g.subplots[0,0]
    ax.axhline(params[1], color='gray', ls='--')
    ax.axvline(params[0], color='gray', ls='--')
    ax.plot(np.nan, color='k', label='True')
    ax.plot(np.nan, color='red', label='MOPED')
    ax.legend(fontsize=8)
    plt.show()
