# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
from getdist import plots, MCSamples
import sys
sys.path.append('../python')
import utils
import threepoint
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def extract_chisq_2pt_map3(num):
    blind = False
    sim = utils.read_cosmosis_mcmc_des_chain('../output/noisy-dv-validation/cosmogrid-2pt-map3-all-noisy-dv-'+str(num)+'.txt', to_mcsamples=True, blind=blind)
    like_array = sim['like']
    val = np.max(like_array)
    return(-2*val)

# %%
def extract_chisq_blind_analysis():
    blind = False
    sim = utils.read_cosmosis_mcmc_des_chain('../output/blind-metacal-8arcmincut/des-y3-2pt-map3-all-blind-metacal.txt', to_mcsamples=True, blind=blind)
    like_array = sim['like']
    val = np.max(like_array)
    return(-2*val)

# %%
def extract_chisq_2pt_blind_analysis():
    blind = False
    sim = utils.read_cosmosis_mcmc_des_chain('../output/blind-metacal-updatedcov/des-y3-2pt-blind-metacal-simcov.txt', to_mcsamples=True, blind=blind)
    like_array = sim['like']
    val = np.max(like_array)
    return(-2*val)

# %%
def extract_diff_s8(num):
    blind = False
    sim = utils.read_cosmosis_mcmc_des_chain('../output/noisy-dv-validation/cosmogrid-2pt-map3-all-noisy-dv-'+str(num)+'.txt', to_mcsamples=True, blind=blind)
    s8 = sim.getMeans()[4]
    print(num)
    sim_2pt = utils.read_cosmosis_mcmc_des_chain('../output/noisy-dv-validation/cosmogrid-2pt-noisy-dv-'+str(num)+'.txt', to_mcsamples=True, blind=blind)
    s8_2pt = sim_2pt.getMeans()[4]
    diff = s8 - s8_2pt
    return(diff)

# %%
def extract_diff_s8_blind():
    blind = False
    sim = utils.read_cosmosis_mcmc_des_chain('../output/blind-metacal-cosmogridcutcov/des-y3-2pt-map3-all-blind-metacal.txt', to_mcsamples=True, blind=blind)
    s8 = sim.getMeans()[4]
    sim_2pt = utils.read_cosmosis_mcmc_des_chain('../output/blind-metacal-updatedcov/des-y3-2pt-blind-metacal-simcov.txt', to_mcsamples=True, blind=blind)
    s8_2pt = sim_2pt.getMeans()[4]
    diff = s8 - s8_2pt
    return(diff)

# %%
blnd = extract_chisq_blind_analysis()
print(blnd)

s8blind = extract_diff_s8_blind()
print(s8blind)

blnd_2pt = extract_chisq_2pt_blind_analysis()
# Out:
# Removed no burn in
# 76.5052926678579
# Removed no burn in
# Removed no burn in
# 0.022231350068733113
# Removed no burn in

# %%
chisq = []
for i in range(50):
    chisq.append(extract_chisq_2pt_map3(i))
print(chisq)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# [72.3426914406441, 45.88708835361099, 72.21406794882563, 61.84225389902092, 71.75263872253272, 82.64551446918834, 78.71251697598916, 60.851023259385215, 68.44165288799677, 68.65739364718367, 69.44527256382514, 74.33032151782876, 81.41230140083134, 81.81487682361441, 63.11481443730856, 97.08972368553145, 73.95797912643299, 88.77467147662873, 56.88384035322171, 73.77617643835069, 76.52386706489617, 83.70599271667827, 66.89260078787585, 73.72992944908788, 82.46678011858342, 69.60656981292138, 71.00541237722811, 82.95171242883109, 80.86403733371571, 54.20578329538304, 68.54055255801259, 90.48896887379904, 90.8191457682257, 62.48447603829128, 68.6077134006923, 62.8744155304457, 70.59442064586818, 64.88408635237943, 61.80877886120696, 72.30869273769476, 76.66766639585973, 65.06370916766207, 85.11120051125465, 65.33242306142922, 68.9111886959289, 79.19723648756965, 79.17145845573431, 62.85989665447103, 84.6407279988726, 57.90455613976269]

# %%
import matplotlib.pyplot as plt
plt.hist(chisq, 15, color='gray')
plt.axvline(x=81.7, color='r', ls=':', linewidth=2)
plt.xlim(30,110)
plt.show()
#plt.savefig("Chisq_PARTIALtest_oct25.pdf")

# %%
diffs = []
for i in range(50):
    if i!=26:
        s8diff = extract_diff_s8(i)
        diffs.append(s8diff)
print(diffs)
# Out:
# Removed no burn in
# 0
# Removed no burn in
# Removed no burn in
# 1
# Removed no burn in
# Removed no burn in
# 2
# Removed no burn in
# Removed no burn in
# 3
# Removed no burn in
# Removed no burn in
# 4
# Removed no burn in
# Removed no burn in
# 5
# Removed no burn in
# Removed no burn in
# 6
# Removed no burn in
# Removed no burn in
# 7
# Removed no burn in
# Removed no burn in
# 8
# Removed no burn in
# Removed no burn in
# 9
# Removed no burn in
# Removed no burn in
# 10
# Removed no burn in
# Removed no burn in
# 11
# Removed no burn in
# Removed no burn in
# 12
# Removed no burn in
# Removed no burn in
# 13
# Removed no burn in
# Removed no burn in
# 14
# Removed no burn in
# Removed no burn in
# 15
# Removed no burn in
# Removed no burn in
# 16
# Removed no burn in
# Removed no burn in
# 17
# Removed no burn in
# Removed no burn in
# 18
# Removed no burn in
# Removed no burn in
# 19
# Removed no burn in
# Removed no burn in
# 20
# Removed no burn in
# Removed no burn in
# 21
# Removed no burn in
# Removed no burn in
# 22
# Removed no burn in
# Removed no burn in
# 23
# Removed no burn in
# Removed no burn in
# 24
# Removed no burn in
# Removed no burn in
# 25
# Removed no burn in
# Removed no burn in
# 27
# Removed no burn in
# Removed no burn in
# 28
# Removed no burn in
# Removed no burn in
# 29
# Removed no burn in
# Removed no burn in
# 30
# Removed no burn in
# Removed no burn in
# 31
# Removed no burn in
# Removed no burn in
# 32
# Removed no burn in
# Removed no burn in
# 33
# Removed no burn in
# Removed no burn in
# 34
# Removed no burn in
# Removed no burn in
# 35
# Removed no burn in
# Removed no burn in
# 36
# Removed no burn in
# Removed no burn in
# 37
# Removed no burn in
# Removed no burn in
# 38
# Removed no burn in
# Removed no burn in
# 39
# Removed no burn in
# Removed no burn in
# 40
# Removed no burn in
# Removed no burn in
# 41
# Removed no burn in
# Removed no burn in
# 42
# Removed no burn in
# Removed no burn in
# 43
# Removed no burn in
# Removed no burn in
# 44
# Removed no burn in
# Removed no burn in
# 45
# Removed no burn in
# Removed no burn in
# 46
# Removed no burn in
# Removed no burn in
# 47
# Removed no burn in
# Removed no burn in
# 48
# Removed no burn in
# Removed no burn in
# 49
# Removed no burn in
# [0.02457992860078706, 0.003470539424545005, -0.008910287465855649, 0.013827639033407557, -0.00031618953700585095, 0.004752483524420703, -0.008242567980251247, 0.011494551062332325, 0.0062636001714717615, 0.004512331243261336, -0.015625091996163132, 0.006362803813954376, 0.010109925428138045, 0.04833086006685161, 0.004855875399926379, 0.010183323930382127, 0.008925818093143634, 0.010442707007663476, 0.015609334679156706, 0.007530972861377272, 0.028459527938824336, 0.01624943103819898, -0.0027447498919654922, 0.0220748183699625, 0.03438971808443381, 0.016136503339557517, 0.02784736586162928, 0.010386317274818313, 0.008730750888380157, 0.011933767805243578, 0.015952574587302704, 0.019846757753857247, -0.0071432187246183165, 0.009649057246294723, -0.00139052699311637, 0.00040067685696687505, 0.019820634982779528, 0.006275131817737534, 0.009568668637180311, 0.01814464922502479, 0.007982890272354881, 0.010507546586682293, 0.01220882160920167, 0.029172029616720274, -0.0049759352937442936, 0.018909326744914856, 0.0035830327983746857, 0.02927696523072465, 0.01672033289887853]

# %%
plt.hist(diffs, 18, color='gray')
plt.axvline(x=0.022231, color='r', ls=':', linewidth=2)
#plt.show()
plt.savefig("s8_diff_fig_OCT25PARTIAL_TEST.pdf")

# %%
j=0
for i in range(len(diffs)):
    if diffs[i]> 0.02422:
        j+=1
j=j/len(diffs)
print(j)
# Out:
# 0.14285714285714285

# %%
#Comparison with bootstrap/jackknife w/randomization:

my_cov = fits.open('../data/covariance/xip_xim_map3_covariance_MORECUT_24Oct24.fits')

def chisq_auto_only(cov, zbin):
    
    indices = [0,10,16,19]
    sm = 400+indices[zbin-1]*4
    lg = 400+(indices[zbin-1]+1)*4
    autocov = my_cov[1].data[sm:lg,:][:,sm:lg]
    
#First we load the auto-iii-only part of our cov
